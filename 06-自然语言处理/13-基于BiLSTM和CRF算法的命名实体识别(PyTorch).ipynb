# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#实战：BiLSTM+CRF进行词性标注" data-toc-modified-id="实战：BiLSTM+CRF进行词性标注-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>实战：<code>BiLSTM+CRF</code>进行词性标注</a></span><ul class="toc-item"><li><span><a href="#模型" data-toc-modified-id="模型-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>模型</a></span><ul class="toc-item"><li><span><a href="#BiLSTM模型" data-toc-modified-id="BiLSTM模型-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span><code>BiLSTM</code>模型</a></span></li><li><span><a href="#BiLSTM_CRF模型" data-toc-modified-id="BiLSTM_CRF模型-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span><code>BiLSTM_CRF</code>模型</a></span><ul class="toc-item"><li><span><a href="#CRF层" data-toc-modified-id="CRF层-1.1.2.1"><span class="toc-item-num">1.1.2.1&nbsp;&nbsp;</span><code>CRF</code>层</a></span></li><li><span><a href="#BiLSTM+CRF" data-toc-modified-id="BiLSTM+CRF-1.1.2.2"><span class="toc-item-num">1.1.2.2&nbsp;&nbsp;</span><code>BiLSTM+CRF</code></a></span></li></ul></li></ul></li><li><span><a href="#数据集" data-toc-modified-id="数据集-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>数据集</a></span><ul class="toc-item"><li><span><a href="#数据预处理" data-toc-modified-id="数据预处理-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>数据预处理</a></span></li><li><span><a href="#创建数据管道" data-toc-modified-id="创建数据管道-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>创建数据管道</a></span></li></ul></li><li><span><a href="#训练模型" data-toc-modified-id="训练模型-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>训练模型</a></span><ul class="toc-item"><li><span><a href="#BiLSTM" data-toc-modified-id="BiLSTM-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>BiLSTM</a></span></li></ul></li><li><span><a href="#转移矩阵" data-toc-modified-id="转移矩阵-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>转移矩阵</a></span></li></ul></li><li><span><a href="#TODO" data-toc-modified-id="TODO-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>TODO</a></span></li></ul></div>

# %% [markdown]
# # 实战：`BiLSTM+CRF`进行词性标注

# %% [markdown]
# ## 模型

# %%
import torch
import torch.nn as nn

# %% [markdown]
# ### `BiLSTM`模型
# ```
#   input_ids:   (batch, seq)
# --> Embedding: (batch, seq, embedding_dim)
# --> LSTM:      (batch, seq, hidden_dim)
# --> Dropout
# --> Linear:    (batch, seq, num_tags)
#
# + targets:     (batch, seq)
# --> loss
# ```
# 训练时：模型 **前向计算**`(forward)` 输出序列的预测标签的概率分布，然后与真实标签计算损失，并进行训练
# 预测时：模型输出序列的预测标签的概率分布，求最大值即为结果

# %%
class NERLSTM(nn.Module):
    def __init__(self, embedding_dim, hidden_dim, dropout, word2id, tag2id):
        super(NERLSTM, self).__init__()

        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.vocab_size = len(word2id) + 1
        self.tag_to_ix = tag2id
        self.num_tags = len(tag2id)

        self.word_embeds = nn.Embedding(self.vocab_size, self.embedding_dim)
        self.dropout = nn.Dropout(dropout)
        self.lstm = nn.LSTM(
            self.embedding_dim,
            self.hidden_dim // 2,
            num_layers=1,
            bidirectional=True,
            batch_first=True, # 该属性设置后，需要特别注意数据的形状
        )
        self.hidden2tag = nn.Linear(self.hidden_dim, self.num_tags)

    def forward(self, x):
        batch_size = x.size(0)
        sent_len = x.size(1)
        embedding = self.word_embeds(x)
        outputs, hidden = self.lstm(embedding)
        outputs = self.dropout(outputs)
        outputs = self.hidden2tag(outputs)
        return outputs

# %% [markdown]
# ### `BiLSTM_CRF`模型

# %% [markdown]
# #### `CRF`层
# - `forward`方法用来计算损失
# - `vertibi_decode`方法用来获的最佳序列

# %%
# https://github.com/s14t284/TorchCRF/blob/master/TorchCRF/__init__.py
from typing import List, Optional

import torch
import torch.nn as nn
from torch import BoolTensor, FloatTensor, LongTensor


class CRF(nn.Module):
    CUDA = torch.cuda.is_available()

    def __init__(self,
                 num_labels: int,
                 pad_idx: Optional[int] = None,
                 use_gpu: bool = True) -> None:
        """
        :param num_labels: number of labels
        :param pad_idxL padding index. default None
        :return None
        """

        CRF.CUDA = CRF.CUDA and use_gpu
        if num_labels < 1:
            raise ValueError(
                "invalid number of labels: {0}".format(num_labels))

        super().__init__()
        self.num_labels = num_labels
        device = "cuda" if CRF.CUDA else "cpu"

        # 遷移行列の設定
        # 遷移行列のフォーマット (遷移元, 遷移先)
        # transition matrix setting
        # transition matrix format (source, destination)
        self.trans_matrix = FloatTensor(num_labels, num_labels).to(device)
        # 先頭と末尾への遷移行列の設定
        # transition matrix of start and end settings
        self.start_trans = FloatTensor(num_labels).to(device)
        self.end_trans = FloatTensor(num_labels).to(device)

        self._initialize_parameters(pad_idx)

        self.trans_matrix = nn.Parameter(self.trans_matrix)
        self.start_matrix = nn.Parameter(self.start_trans)
        self.end_matrix = nn.Parameter(self.end_trans)

    def forward(self, h: FloatTensor, labels: LongTensor,
                mask: BoolTensor) -> FloatTensor:
        """
        :param h: hidden matrix (seq_len, batch_size, num_labels)
        :param labels: answer labels of each sequence
                       in mini batch (seq_len, batch_size)
        :param mask: mask tensor of each sequence
                     in mini batch (seq_len, batch_size)
        :return: The log-likelihood (batch_size)
        """

        log_numerator = self._compute_numerator_log_likelihood(h, labels, mask)
        log_denominator = self._compute_denominator_log_likelihood(h, mask)

        return log_numerator - log_denominator

    def viterbi_decode(self, h: FloatTensor,
                       mask: BoolTensor) -> List[List[int]]:
        """
        decode labels using viterbi algorithm
        :param h: hidden matrix (batch_size, seq_len, num_labels)
        :param mask: mask tensor of each sequence
                     in mini batch (seq_len, batch_size)
        :return: labels of each sequence in mini batch
        """

        batch_size, seq_len, _ = h.size()
        # 各系列の系列長を用意
        # prepare the sequence lengths in each sequence
        seq_lens = mask.long().sum(dim=1)
        # バッチ内において，スタート地点から先頭のラベルに対してのスコアを用意
        # In mini batch, prepare the score
        # from the start sequence to the first label
        score = [self.start_trans.data + h[:, 0]]
        path = []

        for t in range(1, seq_len):
            # 1つ前の系列のスコアを抽出
            # extract the score of previous sequence
            # (batch_size, num_labels, 1)
            previous_score = score[t - 1].view(batch_size, -1, 1)

            # 系列の隠れ層のスコアを抽出
            # extract the score of hidden matrix of sequence
            # (batch_size, 1, num_labels)
            h_t = h[:, t].view(batch_size, 1, -1)

            # t-1の系列のラベルからtの系列のラベルまでの遷移におけるスコアを抽出
            # self.trans_matrixは系列Aから系列Bまでの遷移のスコアを持っている
            # extract the score in transition
            # from label of t-1 sequence to label of sequence of t
            # self.trans_matrix has the score of the transition
            # from sequence A to sequence B
            # (batch_size, num_labels, num_labels)
            score_t = previous_score + self.trans_matrix + h_t

            # 導出したスコアのうち，各系列の最大値と最大値をとり得る位置を保持
            # keep the maximum value
            # and point where maximum value of each sequence
            # (batch_size, num_labels)
            best_score, best_path = score_t.max(1)
            score.append(best_score)
            path.append(best_path)

        # バッチ内のラベルを推定
        # predict labels of mini batch
        best_paths = [
            self._viterbi_compute_best_path(i, seq_lens, score, path)
            for i in range(batch_size)
        ]

        return best_paths

    def _viterbi_compute_best_path(
            self,
            batch_idx: int,
            seq_lens: torch.LongTensor,
            score: List[FloatTensor],
            path: List[torch.LongTensor],
    ) -> List[int]:
        """
        return labels using viterbi algorithm
        :param batch_idx: index of batch
        :param seq_lens: sequence lengths in mini batch (batch_size)
        :param score: transition scores of length max sequence size
                      in mini batch [(batch_size, num_labels)]
        :param path: transition paths of length max sequence size
                     in mini batch [(batch_size, num_labels)]
        :return: labels of batch_idx-th sequence
        """

        seq_end_idx = seq_lens[batch_idx] - 1
        # 系列の一番後ろのラベルを抽出
        # extract label of end sequence
        _, best_last_label = (score[seq_end_idx][batch_idx] +
                              self.end_trans).max(0)
        best_labels = [int(best_last_label)]

        # viterbiアルゴリズムにより，ラベルを後ろから推定
        # predict labels from back using viterbi algorithm
        for p in reversed(path[:seq_end_idx]):
            best_last_label = p[batch_idx][best_labels[0]]
            best_labels.insert(0, int(best_last_label))

        return best_labels

    def _compute_denominator_log_likelihood(self, h: FloatTensor,
                                            mask: BoolTensor):
        """
        compute the denominator term for the log-likelihood
        :param h: hidden matrix (batch_size, seq_len, num_labels)
        :param mask: mask tensor of each sequence
                     in mini batch (batch_size, seq_len)
        :return: The score of denominator term for the log-likelihood
        """

        batch_size, seq_len, _ = h.size()
        # 計算できるよう，遷移行列のサイズを変更
        # (num_labels, num_labels) -> (1, num_labels, num_labels)
        trans = self.trans_matrix.view(1, self.num_labels, self.num_labels)
        # 先頭から各ラベルへのスコアと各ラベルの1番目のスコアを足し合わせる
        # add the score from beginning to each label
        # and the first score of each label
        score = self.start_trans.view(1, -1) + h[:, 0]
        # ミニバッチ中の単語数だけ処理を行う
        # iterate through processing for the number of words in the mini batch
        for t in range(1, seq_len):
            # (batch_size, self.num_labels, 1)
            before_score = score.view(batch_size, self.num_labels, 1)
            # 各系列の系列のt番目のマスクを用意
            # prepare t-th mask of sequences in each sequence
            # (batch_size, 1)
            mask_t = mask[:, t].view(batch_size, 1).type(torch.BoolTensor)
            mask_t = mask_t.cuda() if CRF.CUDA else mask_t

            # 各系列におけるt番目の系列ラベルの遷移確率
            # prepare the transition probability of the t-th sequence label
            # in each sequence
            # (batch_size, 1, num_labels)
            h_t = h[:, t].view(batch_size, 1, self.num_labels)
            # 各系列でのt番目のスコアを導出
            # calculate t-th scores in each sequence
            # (batch_size, num_labels)
            score_t = self.logsumexp(before_score + h_t + trans, 1)
            # スコアの更新
            # update scores
            # (batch_size, num_labels)
            score = score_t * mask_t + score * (~mask_t)

        # 末尾のスコアを足し合わせる
        # add the end score of each label
        score += self.end_trans.view(1, -1)
        # ミニバッチ中のデータ全体の対数尤度を返す
        # return the log likely food of all data in mini batch
        return self.logsumexp(score, 1)

    def _compute_numerator_log_likelihood(self, h: FloatTensor, y: LongTensor,
                                          mask: BoolTensor) -> FloatTensor:
        """
        compute the numerator term for the log-likelihood
        :param h: hidden matrix (batch_size, seq_len, num_labels)
        :param y: answer labels of each sequence
                  in mini batch (batch_size, seq_len)
        :param mask: mask tensor of each sequence
                     in mini batch (batch_size, seq_len)
        :return: The score of numerator term for the log-likelihood
        """

        batch_size, seq_len, _ = h.size()
        # 系列のスタート位置のベクトルを抽出
        # extract first vector of sequences in mini batch
        score = self.start_trans[y[:, 0]]

        h = h.unsqueeze(-1)
        trans = self.trans_matrix.unsqueeze(-1)

        for t in range(seq_len - 1):
            mask_t = mask[:, t].cuda() if CRF.CUDA else mask[:, t]
            mask_t1 = mask[:, t + 1] if CRF.CUDA else mask[:, t + 1]
            # t+1番目のラベルのスコアを抽出
            # extract the score of t+1 label
            # (batch_size)
            h_t = torch.cat([h[b, t, y[b, t]] for b in range(batch_size)])
            # t番目のラベルからt+1番目のラベルへの遷移スコアを抽出
            # extract the transition score from t-th label to t+1 label
            # (batch_size)
            trans_t = torch.cat([trans[s[t], s[t + 1]] for s in y])
            # 足し合わせる
            # add the score of t+1 and the transition score
            # (batch_size)
            score += h_t * mask_t + trans_t * mask_t1

        # バッチ内の各系列の最後尾のラベル番号を抽出する
        # extract end label number of each sequence in mini batch
        # (batch_size)
        last_mask_index = mask.long().sum(1) - 1
        last_labels = y.gather(1, last_mask_index.unsqueeze(-1))
        # hの形を元に戻す
        # restore the shape of h
        h = h.unsqueeze(-1).view(batch_size, seq_len, self.num_labels)

        # バッチ内の最大長の系列のスコアを足し合わせる
        # Add the score of the sequences of the maximum length in mini batch
        score += h[:, -1].gather(1, last_labels).squeeze(1) * mask[:, -1]
        # 各系列の最後尾のタグからEOSまでのスコアを足し合わせる
        # Add the scores from the last tag of each sequence to EOS
        score += self.end_trans[last_labels].view(batch_size)

        return score

    def _initialize_parameters(self, pad_idx: Optional[int]) -> None:
        """
        initialize transition parameters
        :param: pad_idx: if not None, additional initialize
        :return: None
        """

        nn.init.uniform_(self.trans_matrix, -0.1, 0.1)
        nn.init.uniform_(self.start_trans, -0.1, 0.1)
        nn.init.uniform_(self.end_trans, -0.1, 0.1)
        if pad_idx is not None:
            self.start_trans[pad_idx] = -10000.0
            self.trans_matrix[pad_idx, :] = -10000.0
            self.trans_matrix[:, pad_idx] = -10000.0
            self.trans_matrix[pad_idx, pad_idx] = 0.0

    @staticmethod
    def logsumexp(x: FloatTensor, dim: int) -> FloatTensor:
        """
        return log(sum(exp(x))) while minimizing
                                the possibility of overflow/underflow.
        :param x: the matrix format FloatTensor
        :param dim: dimensiton
        :return: log(sum(exp(x)))
        """

        vmax, _ = x.max(dim)
        return vmax + torch.log(
            torch.sum(torch.exp(x - vmax.unsqueeze(dim)), dim))

# %%
device = torch.device('cuda' if torch.cuda.is_available else 'cpu')

batch_size = 2
seq_len = 3
num_labels = 5

# 掩码，表示序列中哪些元素是填充的
mask = torch.ByteTensor([[1, 1, 1], [1, 1, 0]]).to(device)

# 真实的序列标签
labels = torch.LongTensor([[0, 2, 3], [1, 4, 1]]).to(device)

# LSTM层的输出，表示预测的 序列标签概率分布
hidden = torch.randn((batch_size, seq_len, num_labels),
                     requires_grad=True).to(device)

# %%
# 创建模型，只需要提供 标签 数量
crf = CRF(num_labels)

# 提供LSTM层输出的序列标签分布，和真实标签，前向计算获得损失
crf.forward(hidden, labels, mask)
# Out:
# tensor([-5.7249, -5.4133], device='cuda:0', grad_fn=<SubBackward0>)

# %%
# 根据 预测的 序列标签概率分布 进行解码，获得最佳序列
crf.viterbi_decode(hidden, mask)
# Out:
# [[0, 1, 1], [0, 2]]

# %% [markdown]
# #### `BiLSTM+CRF`
# ```
# input_ids:                       (batch, seq)
# --> Embedding:                   (batch, seq, embedding_dim)
# --> LSTM:                        (batch, seq, hidden_dim)
# --> Dropout
# --> Linear:                      (batch, seq, num_tags)
# --> CRF
# ```
# 训练时：模型直接调用`log_likelihood`方法计算损失，然后进行训练
#    - 此时模型内部，线性层的 输出和目标 一起经过 CRF 的**前向计算`forward`**得到损失
#
# 预测时：模型 **前向计算`forward`** 获得输出序列
#    - 此时模型内部，线性层的 输出 经过 CRF 的解码方法计算得到预测标签序列

# %%
class NERLSTM_CRF(nn.Module):
    def __init__(self, config):
        super(NERLSTM_CRF, self).__init__()

        self.embedding_dim = config.embedding_dim
        self.hidden_dim = config.hidden_dim
        self.vocab_size = config.vocab_size
        self.num_tags = config.num_tags

        self.embeds = nn.Embedding(self.vocab_size, self.embedding_dim)
        self.dropout = nn.Dropout(config.dropout)

        self.lstm = nn.LSTM(
            self.embedding_dim,
            self.hidden_dim // 2,
            num_layers=1,
            bidirectional=True,
            batch_first=True,  # 该属性设置后，需要特别注意数据的形状
        )

        self.linear = nn.Linear(self.hidden_dim, self.num_tags)

        # CRF 层
        self.crf = CRF(self.num_tags)

    def forward(self, x, mask):
        embeddings = self.embeds(x)
        feats, hidden = self.lstm(embeddings)
        emissions = self.linear(self.dropout(feats))
        outputs = self.crf.viterbi_decode(emissions, mask)
        return outputs

    def log_likelihood(self, x, labels, mask):
        embeddings = self.embeds(x)
        feats, hidden = self.lstm(embeddings)
        emissions = self.linear(self.dropout(feats))
        loss = -self.crf.forward(emissions, labels, mask)
        return torch.sum(loss)

# %%
# 测试模型

class Config():
    embedding_dim = 6
    hidden_dim = 20
    vocab_size = 50
    num_tags = 5
    dropout = 0.1


config = Config()
model = NERLSTM_CRF(config).to(device)

# %%
x = torch.LongTensor([[1, 12, 31, 4, 15], [2, 18, 39, 14, 0]]).to(device)
mask = torch.BoolTensor([[1, 1, 1, 1, 1], [1, 1, 1, 1, 0]]).to(device)
labels = torch.LongTensor([[1, 2, 1, 3, 0], [2, 4, 2, 1, 0]]).to(device)

# 解码
model.forward(x, mask)
# Out:
# [[2, 2, 3, 3, 3], [1, 2, 2, 2]]

# %% [markdown]
# > 数据类型为：`torch.int64`

# %%
# 计算损失
model.log_likelihood(x, labels, mask)
# Out:
# tensor(14.6996, device='cuda:0', grad_fn=<SumBackward0>)

# %% [markdown]
# ## 数据集
# 原始数据来自人民日报，处理成如下形式：
# ```
# 迈向/v  充满/v  希望/n  的/u  新/a  世纪/n
# ```
# 主要分为三类：nr,ns,nt
# >nr | 人名
# ns | 地名
# nt | 机构名
#
#
# 并用以下标识：
#
# > B | 词首
# M | 词中
# E | 词尾
# O | 单字

# %% [markdown]
# ### 数据预处理

# %%
# https://github.com/buppt/ChineseNER/blob/master/data/renMinRiBao/data_renmin_word.py
import os
import codecs
import re
import pdb
import pandas as pd
import numpy as np
import collections
import pickle


def originHandle():
    # 将 多空格 隔开的连续的标注数据: "中共中央/nt  总书记/n  、/w  国家/n  主席/n"，转化成单空格

    with open('../datasets/ner/renmin/renmin.txt',
              'r') as inp, open('../datasets/ner/renmin/renmin2.txt',
                                'w') as outp:
        for line in inp.readlines():
            line = line.split('  ')
            i = 1  # 删除每一行第一个标注数据，为时间 "19980101-01-001-016/m"
            while i < len(line) - 1:

                # 1. [北京/ns  石景山/ns  发电/vn  总厂/n]nt --> 北京石景山发电总厂/nt
                ################################################################
                if line[i][0] == '[':
                    outp.write(line[i].split('/')[0][1:])
                    i += 1
                    while i < len(line) - 1 and line[i].find(']') == -1:
                        if line[i] != '':
                            outp.write(line[i].split('/')[0])
                        i += 1
                    outp.write(line[i].split('/')[0].strip() + '/' +
                               line[i].split('/')[1][-2:] + ' ')

                # 2. 将连续的两个 nr 标签单词连接起来，如 姓+名
                ################################################################
                elif line[i].split('/')[1] == 'nr':
                    word = line[i].split('/')[0]
                    i += 1
                    if i < len(line) - 1 and line[i].split('/')[1] == 'nr':
                        outp.write(word + line[i].split('/')[0] + '/nr ')
                    else:
                        outp.write(word + '/nr ')
                        continue
                else:
                    outp.write(line[i] + ' ')
                i += 1
            outp.write('\n')


def originHandle2():
    # 将 单词+标注，转换成 字+标注；字的标注表示为 字在单词中的位置+单词的标注，如 "中国"
    with codecs.open('../datasets/ner/renmin/renmin2.txt', 'r',
                     'utf-8') as inp, codecs.open(
                         '../datasets/ner/renmin/renmin3.txt', 'w',
                         'utf-8') as outp:
        for line in inp.readlines():
            line = line.split(' ')
            i = 0
            while i < len(line) - 1:
                if line[i] == '':
                    i += 1
                    continue
                word = line[i].split('/')[0]
                tag = line[i].split('/')[1]

                # 1. 只保留这三种标注：nr , ns , nt
                # 中共中央/nt 总书记/n 、/w 国家/n 主席/n 江泽民/nr -->
                # 中/B_nt 共/M_nt 中/M_nt 央/E_nt 总/O 书/O 记/O 、/O 国/O 家/O 主/O 席/O 江/B_nr 泽/M_nr 民/E_nr
                ###########################################################################################
                if tag == 'nr' or tag == 'ns' or tag == 'nt':
                    outp.write(word[0] + "/B_" + tag + " ")
                    for j in word[1:len(word) - 1]:
                        if j != ' ':
                            outp.write(j + "/M_" + tag + " ")
                    outp.write(word[-1] + "/E_" + tag + " ")

                # 2. 其它的标注都转变成 '/O'
                else:
                    for wor in word:
                        outp.write(wor + '/O ')
                i += 1
            outp.write('\n')


def sentence2split():
    with open('../datasets/ner/renmin/renmin3.txt',
              'r') as inp, codecs.open('../datasets/ner/renmin/renmin4.txt',
                                       'w', 'utf-8') as outp:
        texts = inp.read()  # .decode('utf-8')

        # 按 标点符号 分成拆分成子句，每个子句为一行
        sentences = re.split('[，。！？、‘’“”:]/[O]', texts)
        for sentence in sentences:
            if sentence != " ":
                outp.write(sentence.strip() + '\n')

# originHandle()
# originHandle2()
# sentence2split()

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences


def data2pkl():
    datas = list()
    labels = list()

    all_words = []
    tags = set()

    input_data = codecs.open('../datasets/ner/renmin/renmin4.txt', 'r',
                             'utf-8')

    # 1. 将标注子句 拆分成 字列表 和 对应的标注列表 #############
    #####################################################
    for line in input_data.readlines():
        linedata = list()
        linelabel = list()

        line = line.split()

        numNotO = 0
        for word in line:
            word = word.split('/')
            linedata.append(word[0])
            linelabel.append(word[1])

            all_words.append(word[0])
            tags.add(word[1])

            if word[1] != 'O':  # 标注全为 O 的子句
                numNotO += 1

        if numNotO != 0:  # 只保存 标注不全为 O 的子句
            #             print(linedata)
            datas.append(linedata)
            labels.append(linelabel)

    input_data.close()
    print("文本序列的数量：", len(datas))  # 字列表 组成的列表
    assert (len(labels) == len(datas))  # 对应的 标注列表 组成的列表
    print("文本所有单词数：", len(all_words))

    # 2. 创建词汇表和标签表 ################################
    #####################################################

    words_count = collections.Counter(all_words).most_common()
    word2id = {word: i for i, (word, _) in enumerate(words_count, 1)}
    word2id["[PAD]"] = 0
    word2id["[unknown]"] = len(word2id)

    id2word = {i: word for word, i in word2id.items()}
    print("词汇表的大小：", len(id2word))

    print("所有标签：", tags)
    tag2id = {tag: i for i, tag in enumerate(tags)}
    print(tag2id)

    id2tag = {i: tag for tag, i in tag2id.items()}
    print(id2tag)

    print("-" * 100)
    print("Buiding vocab Done!!!")

    # 3. 数据向量化，并处理成相同长度 ########################
    #####################################################
    max_len = 60

    data_ids = [[word2id[w] for w in line] for line in datas]
    label_ids = [[tag2id[t] for t in line] for line in labels]

    x = pad_sequences(data_ids, maxlen=max_len, padding='post').astype(np.int64)
    y = pad_sequences(label_ids, maxlen=max_len, padding='post').astype(np.int64)

    print("-" * 100)
    print("Vectorizing data Done!!!")

    # 4. 向量化后数据拆分成训练集、验证集、测试集 ##############
    #####################################################
    from sklearn.model_selection import train_test_split
    x_train, x_test, y_train, y_test = train_test_split(
        x,
        y,
        test_size=0.2,
        random_state=43,
    )
    x_train, x_valid, y_train, y_valid = train_test_split(
        x_train,
        y_train,
        test_size=0.2,
        random_state=43,
    )

    print("-" * 100)
    print("Splitting data Done!!!")

    # 5. 保存数据 ########################
    #####################################################

    import pickle
    import os
    with open('../datasets/ner/renmin/renmindata.pkl', 'wb') as outp:
        pickle.dump(word2id, outp)
        pickle.dump(id2word, outp)
        pickle.dump(tag2id, outp)
        pickle.dump(id2tag, outp)

        pickle.dump(x_train, outp)
        pickle.dump(y_train, outp)

        pickle.dump(x_test, outp)
        pickle.dump(y_test, outp)

        pickle.dump(x_valid, outp)
        pickle.dump(y_valid, outp)

    print("-" * 100)
    print('** Finished saving the data.')


# data2pkl()
# Out:
# 文本序列的数量： 37924
# 文本所有单词数： 1690464
# 词汇表的大小： 4683
# 所有标签： {'E_nt', 'M_nt', 'E_nr', 'O', 'B_nr', 'B_ns', 'M_ns', 'E_ns', 'M_nr', 'B_nt'}
# {'E_nt': 0, 'M_nt': 1, 'E_nr': 2, 'O': 3, 'B_nr': 4, 'B_ns': 5, 'M_ns': 6, 'E_ns': 7, 'M_nr': 8, 'B_nt': 9}
# {0: 'E_nt', 1: 'M_nt', 2: 'E_nr', 3: 'O', 4: 'B_nr', 5: 'B_ns', 6: 'M_ns', 7: 'E_ns', 8: 'M_nr', 9: 'B_nt'}
# ----------------------------------------------------------------------------------------------------
# Buiding vocab Done!!!
# ----------------------------------------------------------------------------------------------------
# Vectorizing data Done!!!
# ----------------------------------------------------------------------------------------------------
# Splitting data Done!!!
# ----------------------------------------------------------------------------------------------------
# ** Finished saving the data.

# %%
# 保存预料中所有实体
def save_entities():
    input_data = codecs.open('../datasets/ner/renmin/renmin4.txt', 'r',
                             'utf-8')

    # 保存所有实体 #########################################
    #####################################################

    from collections import defaultdict
    entities = defaultdict(set)

    for line in input_data.readlines():

        line = line.strip().split()
        tokens = [line[i].split('/')[0] for i in range(len(line))]
        tags = [line[i].split('/')[1] for i in range(len(line))]


        start = 0
        end = 0
        for i in range(len(line)):
            token, tag = tokens[i], tags[i]
            if tag.startswith("B"):
                begin = i
            elif tag.startswith("E"):
                end = i
                word = ''.join(tokens[begin:end + 1])
                label = tag[2:]
                entities[label].add(word)
            
    with open('../datasets/ner/renmin/entities.pkl', 'wb') as outp:
        pickle.dump(entities, outp)

# save_entities()

# %%
pickle_path = '../datasets/ner/renmin/entities.pkl'
with open(pickle_path, 'rb') as inp:
    entities = pickle.load(inp)
    
entities['nr']
# Out:
# {'樊萌',
#  '慕凌飞',
#  '母秋华',
#  '曾建徽',
#  '桑燕',
#  '陈焕友',
#  '冼笃信',
#  '路易十四',
#  '托马谢克',
#  '祁秉文',
#  '黄双武',
#  '彭小民',
#  '斯卡拉',
#  '章治文',
#  '张志华',
#  '周志刚',
#  '祝耀祖',
#  '丁传贤',
#  '马本斋',
#  '穆道俊',
#  '陈育明',
#  '李小和',
#  '游本昌',
#  '欧阳修',
#  '李卫天',
#  '于尔根·吕特格尔斯',
#  '卡尔',
#  '姜伯驹',
#  '梁国安',
#  '刘志秋',
#  '石平',
#  '毛宁',
#  '秦蕴珊',
#  '老吴',
#  '龙志毅',
#  '宗良',
#  '许昱华',
#  '程步云',
#  '张衡',
#  '塔尔博特',
#  '高成',
#  '周江波',
#  '李释勘',
#  '王璐瑶',
#  '陈立军',
#  '王继英',
#  '让·米奥',
#  '张琨锐',
#  '谭利华',
#  '阎晓明',
#  '安学发',
#  '郭强',
#  '珠康·土登克珠',
#  '爱丽丝',
#  '陈立夫',
#  '张克俭',
#  '沃勒贝克',
#  '高山岳',
#  '王庆成',
#  '林嘉（马来）',
#  '谢宗惠',
#  '杨伟光',
#  '刘秉义',
#  '王素琴',
#  '赵富林',
#  '石景宜',
#  '齐如山',
#  '李小双',
#  '陈晓红',
#  '亚伯',
#  '姚本棠',
#  '蒋文良',
#  '罗帅',
#  '卓福香',
#  '柳公权',
#  '马瑾',
#  '郭大维',
#  '张淑英',
#  '王夫棠',
#  '王荣志',
#  '黄学锋',
#  '王志新',
#  '吕农华',
#  '张裕民',
#  '侯文学',
#  '约翰·戴维特',
#  '汪啸风',
#  '法比尤斯',
#  '刘宝珍',
#  '闵惠芬',
#  '马思忠',
#  '李默庵',
#  '王文学',
#  '方成',
#  '张雅心',
#  '龚伟瑄',
#  '刘我成',
#  '徐业刚',
#  '曹馨仪',
#  '邓成城',
#  '阿佩尔',
#  '韩磊磊',
#  '吴爱恩',
#  '何添发',
#  '欧阳海',
#  '侏罗纪',
#  '何少存',
#  '朱时茂',
#  '姚信民',
#  '谢峰',
#  '杨阳',
#  '钱云强',
#  '方嘉民',
#  '威廉·莱易斯',
#  '李力',
#  '张学仁',
#  '刘泽仁',
#  '小贾',
#  '毛增滇',
#  '洪成南',
#  '王仲平',
#  '吴敦夫',
#  '张弛',
#  '张同吾',
#  '王永',
#  '洛神',
#  '李清照',
#  '冯炯华',
#  '陆俊',
#  '三博',
#  '约翰·施特劳斯',
#  '玉素甫·艾沙',
#  '瓦尔达斯·阿达姆库斯',
#  '波苏瓦柳克',
#  '林强',
#  '张允',
#  '齐国泉',
#  '米哈伊',
#  '唐云',
#  '潘震宙',
#  '牛绍尧',
#  '王展意',
#  '邹德忠',
#  '沃纳·福诺斯',
#  '安洋',
#  '沃尔斯费尔德',
#  '刘一兵',
#  '程天赋',
#  '牛荣健',
#  '李仁',
#  '刘山在',
#  '王忍之',
#  '魏敏学',
#  '印第安纳·琼斯',
#  '王荩卿',
#  '王燕',
#  '张华祝',
#  '刘希圣',
#  '加米尔',
#  '白燕升',
#  '陆仁达',
#  '克拉泽博格',
#  '斯·费舍尔',
#  '远远',
#  '陈鹏',
#  '叶文虎',
#  '关良',
#  '帕巴荣·卡拉耶',
#  '林万清',
#  '黄金宝',
#  '王植时',
#  '张润霞',
#  '刘桂真',
#  '绢子',
#  '吴觉农',
#  '葛治洲',
#  '严群力',
#  '张礼慧',
#  '魏积安',
#  '赵忠惠',
#  '刘思培',
#  '克洛德·谢松',
#  '秦富明',
#  '袁明',
#  '何柱国',
#  '高振家',
#  '康交阳',
#  '郭佩英',
#  '布拉威',
#  '李克强',
#  '杨成明',
#  '桑原',
#  '宋秋山',
#  '王弭力',
#  '季允石',
#  '段和平',
#  '霍长和',
#  '刘进荣',
#  '刘俊',
#  '叶秀山',
#  '尼亚佐夫',
#  '黄镇东',
#  '罗康瑞',
#  '杨正光',
#  '加蒂',
#  '张谊模',
#  '欧阳山尊',
#  '安南',
#  '解振华',
#  '潘继明',
#  '吴邦国',
#  '伍绍祖',
#  '陶秀',
#  '少颖',
#  '任文燕',
#  '才旦卓玛',
#  '王丹凤',
#  '毛泽东',
#  '卢铁城',
#  '傅天祝',
#  '土井',
#  '朱建安',
#  '杨秀梅',
#  '杨影',
#  '张宁斌',
#  '崔光祖',
#  '加齐沃达',
#  '范瑞娟',
#  '吴雪',
#  '刘洪',
#  '刘来村',
#  '李致忠',
#  '俞荣根',
#  '艾笑',
#  '詹永杰',
#  '王植柔',
#  '俞丽拿',
#  '傅全香',
#  '杨二',
#  '赵金河',
#  '陈乃芳',
#  '赵葆华',
#  '郝跃',
#  '熊辉银',
#  '黄耀荣',
#  '肖天',
#  '罗伯托·阿尔沃雷斯·纪廉',
#  '帕巴蓬·诗里巴尼',
#  '蒋秋霞',
#  '吴国村',
#  '乔榛',
#  '杨性恺',
#  '石永春',
#  '吕杰',
#  '张永根',
#  '谭炎午',
#  '唐博学',
#  '卢功勋',
#  '邓道坤',
#  '韩奇',
#  '汪懋华',
#  '叶荣宝',
#  '李光茹',
#  '马凡贵',
#  '赵太侔',
#  '王廷江',
#  '丘广钟',
#  '方福康',
#  '曲德斌',
#  '皮克林',
#  '孙录',
#  '彭朝晖',
#  '比什凯克',
#  '汪自力',
#  '费希尔',
#  '达庆利',
#  '乌戈·米夫萨德·邦尼奇',
#  '李玉莲',
#  '柳青',
#  '黎庆宁',
#  '梁汝堂',
#  '李念政',
#  '房维中',
#  '王文娟',
#  '李月辉',
#  '包文翊',
#  '张承凤',
#  '郝益东',
#  '张素贞',
#  '石守权',
#  '潘日源',
#  '晓白',
#  '周维',
#  '杨树山',
#  '熊幽',
#  '李星浩',
#  '谢湘',
#  '李长久',
#  '李渭清',
#  '张震康',
#  '陈丽华',
#  '陈绪英',
#  '李介车',
#  '贝恩德',
#  '田京海',
#  '潘永明',
#  '穆斯塔法·本·马苏尔',
#  '厉无畏',
#  '何玉棠',
#  '林风眠',
#  '王立成',
#  '吴泽洲',
#  '丽达',
#  '李学江',
#  '胡德平',
#  '朱振江',
#  '樊福祥',
#  '熊正美',
#  '鲁伊斯',
#  '惠然',
#  '吴天鹏',
#  '孙君梅',
#  '叶青',
#  '龚心瀚',
#  '王淑贤',
#  '孟凤岭',
#  '周志方',
#  '格雷',
#  '柴松岳',
#  '叶宏明',
#  '梁必业',
#  '卢永华',
#  '俞俞',
#  '黄宏',
#  '张广志',
#  '黄军军',
#  '李国华',
#  '克鲁吉',
#  '本·阿里',
#  '刘敦一',
#  '刘志坚',
#  '科恩',
#  '张艺谋',
#  '敖维忠',
#  '马刚',
#  '赵巍巍',
#  '王锡贞',
#  '胡汉方',
#  '李前宽',
#  '赵恩登',
#  '晓江',
#  '振华',
#  '胡忠友',
#  '布场古',
#  '张捷',
#  '朱斌成',
#  '稳波',
#  '周大荣',
#  '勒布朗',
#  '云宣新',
#  '李大强',
#  '莫勒姆',
#  '坚宗',
#  '李昌镐',
#  '管见',
#  '塔斯马尼安',
#  '陈峰玖',
#  '王兰',
#  '王学泰',
#  '林耀基',
#  '邓在军',
#  '王爱花',
#  '巴人',
#  '姬嘉',
#  '刘国典',
#  '胡勇方',
#  '悠棠',
#  '任志强',
#  '李月华',
#  '世庆',
#  '汉卿',
#  '黄团元',
#  '张东波',
#  '林毅夫',
#  '穆索尔斯基',
#  '郭振亚',
#  '阎维文',
#  '江红',
#  '蔡绍芝',
#  '张敏杰',
#  '宋金升',
#  '巴希尔',
#  '洪绂曾',
#  '李景田',
#  '王义明',
#  '李宇鸿',
#  '安金鹏',
#  '丛亚平',
#  '龚学平',
#  '陈淑兰',
#  '周子玉',
#  '格雷厄姆·弗赖',
#  '金日光',
#  '夏守春',
#  '金钟研',
#  '张仁俊',
#  '古可',
#  '小许',
#  '董洪亮',
#  '关隐达',
#  '史照栋',
#  '浦熙修',
#  '冯庆锵',
#  '李国安',
#  '陈大鹏',
#  '冯梯云',
#  '裴艳玲',
#  '孔令仁',
#  '刘明善',
#  '晓周',
#  '夏仲烈',
#  '艾赛义德',
#  '书炜',
#  '罗森加特',
#  '刘少山',
#  '董寅初',
#  '雷蕾',
#  '张海云',
#  '李雁荡',
#  '蒋志伊',
#  '士心',
#  '王锐',
#  '耶稣',
#  '杨孙西',
#  '马夫罗季',
#  '苏平凡',
#  '陈子劲',
#  '盛世良',
#  '陈宜瑜',
#  '艾芜',
#  '龙月美',
#  '周勇',
#  '曹冬蓉',
#  '陶明',
#  '切尔诺梅尔金',
#  '李坤元',
#  '卢家丰',
#  '郑剑',
#  '张耀智',
#  '德梅西纳',
#  '曹龙彪',
#  '海飞',
#  '卢迈',
#  '闻艺',
#  '张涵信',
#  '韩俊',
#  '韦拉亚提',
#  '诺德',
#  '李为昌',
#  '杜毅',
#  '栗前明',
#  '刘洋',
#  '席裕庚',
#  '汪光亮',
#  '胡继高',
#  '张耒',
#  '梁国彪',
#  '王忠家',
#  '李义山',
#  '冯喆',
#  '周小琴',
#  '苏宁',
#  '宋路喜',
#  '雨田',
#  '王世英',
#  '张燮林',
#  '李斌城',
#  '亨廷顿',
#  '郑勇',
#  '田昭武',
#  '傅凌',
#  '高琪',
#  '农德孟',
#  '赵会平',
#  '库恩德科夫',
#  '比尔·盖茨',
#  '武宣',
#  '胡子诚',
#  '张俊兰',
#  '纳韦',
#  '田一明',
#  '何晴',
#  '黄关葆',
#  '胡利奥·鲁伊斯',
#  '史建',
#  '陈澄波',
#  '尹俊',
#  '张东升',
#  '戴受惠',
#  '曹广亮',
#  '埃瑞克·孔泽尔',
#  '李成岁',
#  '方生',
#  '焦林义',
#  '喻长林',
#  '陈虹',
#  '袁晴棠',
#  '王国治',
#  '焦金凤',
#  '胡卫东',
#  '张同盟',
#  '冯钦哉',
#  '张廷武',
#  '青颖',
#  '侯波',
#  '李家明',
#  '陈勉',
#  '郭荣元',
#  '王力平',
#  '葛优',
#  '别克木哈买提·木沙',
#  '沛新小丰',
#  '赵建民',
#  '白景中',
#  '王国平',
#  '任远征',
#  '魏征',
#  '张津雪',
#  '曼·莫汉·阿迪卡里',
#  '傅冬',
#  '桂运东',
#  '费老',
#  '萧关根',
#  '尼克松',
#  '龙新',
#  '周然毅',
#  '王锦鹄',
#  '黄良高',
#  '孔晓宇',
#  '温光春',
#  '余瑛瑞',
#  '高广宾',
#  '汤民仁',
#  '卡翁达',
#  '曾宪梓',
#  '黄其兴',
#  '盛和帮',
#  '杨云',
#  '杨小平',
#  '毕全忠',
#  '袁文耀',
#  '张思恩',
#  '黄伟民',
#  '廖存忠',
#  '布什',
#  '李殿仁',
#  '李兆焯',
#  '谭素英',
#  '宫权',
#  '曾庆红',
#  '王鹤龄',
#  '薛亚清',
#  '徐性初',
#  '姚建年',
#  '谢启美',
#  '诸宸',
#  '邵建武',
#  '刘彦军',
#  '李丽娟',
#  '卫岩',
#  '徐是雄',
#  '傅丁根',
#  '刘海粟',
#  '徐匡迪',
#  '董建勤',
#  '房卫党',
#  '冯光荣',
#  '官天一',
#  '聂永芳',
#  '吴镝鸣',
#  '沈关学',
#  '袁志成',
#  '拉希德',
#  '徐如镜',
#  '龙太新',
#  '高丽生',
#  '刘玉红',
#  '张剑飞',
#  '黄岳忠',
#  '马丹妮',
#  '秦满江',
#  '俞宗杰',
#  '王金城',
#  '陈云龙',
#  '拉鲁·次旺多吉',
#  '伊琳娜',
#  '赖林嵩',
#  '马鸿恩',
#  '刘国强',
#  '鹿中民',
#  '杨晓军',
#  '李祖可',
#  '张左己',
#  '周建安',
#  '孙天义',
#  '蔡元培',
#  '廖望月',
#  '邱廷',
#  '刘明',
#  '夏立宛',
#  '刘于鹤',
#  '朱满庭',
#  '今哲',
#  '冯克熙',
#  '冯雅丽',
#  '冈玻斯',
#  '王瑞璞',
#  '沈德中',
#  '伽马',
#  '齐怀远',
#  '王昕',
#  '章念生',
#  '张鉴祖',
#  '里依斯',
#  '李维屏',
#  '萧娴',
#  '莫华伦',
#  '那努奔',
#  '伏明霞',
#  '吴雁泽',
#  '吴新涛',
#  '鲍绍雄',
#  '麦克·雷蒙',
#  '陈韵',
#  '王明义',
#  '傅民魁',
#  '水天长',
#  '鲁宾',
#  '杨义先',
#  '褚遂良',
#  '龚如心',
#  '莎阿代提·哈米提',
#  '陈德良',
#  '匡吉',
#  '根茨',
#  '徐特立',
#  '赵宝珍',
#  '阿嘉·洛桑图旦·久美加措',
#  '张静',
#  '宋德敏',
#  '张河燕',
#  '清水',
#  '刘永好',
#  '阿平',
#  '庄金宝',
#  '白音',
#  '杨崇汇',
#  '何瑞荣',
#  '萧三',
#  '李永海',
#  '孙先敏',
#  '韩冰岩',
#  '张和平',
#  '徐灵芝',
#  '赵秀娟',
#  '刘文西',
#  '王挺革',
#  '王尧',
#  '撒切尔',
#  '秋山生哉',
#  '阿卡蒂耶夫',
#  '黄天明',
#  '马连良',
#  '徐生岚',
#  '马丽静',
#  '梁德妍',
#  '古莱德',
#  '黄任文',
#  '关本忠弘',
#  '富治',
#  '冬柴铁三',
#  '黎虹',
#  '宝华',
#  '武季梅',
#  '阎肃',
#  '金秀壮',
#  '陆子冈',
#  '文家庭',
#  '陈宗皋',
#  'Ｃ．Ｂ．',
#  '王作义',
#  '杜泰武',
#  '梁平波',
#  '张绍林',
#  '张艳',
#  '齐宪役',
#  '赵连庆',
#  '黄锐',
#  '赵立荣',
#  '张健民',
#  '苏清阳',
#  '胡琳珍',
#  '于力',
#  '利奥波德',
#  '郑一军',
#  '潘家珉',
#  '孟庆祥',
#  '万方',
#  '库克',
#  '周恒',
#  '潘堂林',
#  '师永刚',
#  '安某',
#  '刘春贤',
#  '许根俊',
#  '钱梓弘',
#  '傅汝吉',
#  '张波屏',
#  '刘荣惠',
#  '朱允友',
#  '何祚欢',
#  '松下幸之助',
#  '祁载康',
#  '杨飞',
#  '周方',
#  '苏来兴',
#  '伯塞斯库',
#  '张晔',
#  '胡和颜',
#  '波尔',
#  '戴爱莲',
#  '胡慧娥',
#  '段心强',
#  '袁行霈',
#  '陈镜开',
#  '王露丹',
#  '谢衷洁',
#  '乌叶海亚',
#  '诺哈',
#  '王丰',
#  '童志成',
#  '夏日',
#  '刘兰芳',
#  '朱震刚',
#  '杨发勋',
#  '汪浩',
#  '贾那布尔',
#  '陈毓珍',
#  '王志明',
#  '小余',
#  '胡政光',
#  '老志新',
#  '元也',
#  '哈马·阿马杜',
#  '罗成群',
#  '周玉峰',
#  '陈昌智',
#  '周亮',
#  '华汉生',
#  '张爱萍',
#  '梁爱诗',
#  '张良华',
#  '塔鲁克·谢赫',
#  '詹建俊',
#  '杜延明',
#  '赖四强',
#  '王琦',
#  '赵相如',
#  '小婉',
#  '康淑兰',
#  '卡比拉',
#  '穆加贝',
#  '张玉琛',
#  '蒙美路',
#  '胡静',
#  '刘仲藜',
#  '裕裕',
#  '王文东',
#  '李巨平',
#  '勇军',
#  '贝·布托',
#  '董成宝',
#  '唐敖庆',
#  '鄂青子',
#  '陈砾',
#  '书云玉琴',
#  '穆罕默德',
#  '王云坤',
#  '扶名福',
#  '黄斌',
#  '焦裕禄',
#  '邢贲思',
#  '宋克湘',
#  '陈遇龙',
#  '王之泰',
#  '黄会清',
#  '佟国荣',
#  '赵永生',
#  '雷岩',
#  '周邓',
#  '李敬则',
#  '艾山',
#  '马琳',
#  '徐秀棠',
#  '乔新贤',
#  '卢加斯',
#  '李金建',
#  '三塚博',
#  '刘桂萍',
#  '孙中山',
#  '陈天湖',
#  '阎锡山',
#  '刘荣礼',
#  '雷志敏',
#  '法老王',
#  '多兰',
#  '罗宾·库克',
#  '吴恭让',
#  '苗重安',
#  '艾哈迈德·本·穆罕默德·萨利姆',
#  '岳美缇',
#  '吴博亚',
#  '关公',
#  '张炯强',
#  '高伟',
#  '韦拉',
#  '王尚英',
#  '卢育波',
#  '章学诚',
#  '段柄仁',
#  '徐江善',
#  '蔡子民',
#  '黄瑶',
#  '张凌',
#  '崔河',
#  '八木',
#  '佩塞克',
#  '尤艳春',
#  '崔正华',
#  '张荣典',
#  '徐建荣',
#  '安德雷斯·科尔',
#  '南月明',
#  '季羡林',
#  '跃华黎明',
#  '宋维良',
#  '雅各布·姆万萨·卡宾加',
#  '陈洪顺',
#  '陈雅棠',
#  '王继宣',
#  '佟宝存',
#  '蒋腊摆',
#  '王克',
#  '曾启亮',
#  '张成伦',
#  '赵秀英',
#  '李利君',
#  '范德闽',
#  '高扬文',
#  '张武扬',
#  '蔡海金',
#  '王四代',
#  '李树深',
#  '马国良',
#  '比格尼斯',
#  '谢家树',
#  '吴寿章',
#  '迈纳萨拉',
#  '毕丽梅',
#  '哈立法克斯',
#  '孙自铎',
#  '崔敏',
#  '罗哈斯',
#  '宋连友',
#  '刘德远',
#  '刘诗白',
#  '刘炳森',
#  '吴守一',
#  '江姐',
#  '罗祥国',
#  '秦秀英',
#  '埃弗迪卡哈',
#  '梁国英',
#  '鲁杰罗',
#  '王亚辉',
#  '唐永淑',
#  '陈及霖',
#  '钟德鲁',
#  '查理·曼德',
#  '曾荫权',
#  '李世济',
#  '许广平',
#  '赖庆辉',
#  '逄新学',
#  '吴若秋',
#  '车菊红',
#  '胡明',
#  '史怀璧',
#  '梁植文',
#  '崔士鑫',
#  '陈钢',
#  '陆明远',
#  '李华英',
#  '张岸涛',
#  '黄定元',
#  '孙凤珍',
#  '吴祖强',
#  '张海军',
#  '温凯玉',
#  '王发荣',
#  '龙安定',
#  '周宗欣',
#  '史丰收',
#  '李赣骝',
#  '李象益',
#  '李文辉',
#  '高桂滋',
#  '孙忠良',
#  '张剑',
#  '王凤岐',
#  '邓秀新',
#  '傅铁山',
#  '靳树增',
#  '杨斌庆',
#  '郑必坚',
#  '李铮友',
#  '阿拉济',
#  '于永波',
#  '王巨禄',
#  '杨朝明',
#  '金大中',
#  '陈耀邦',
#  '谢德财',
#  '邢宝明',
#  '万宝瑞',
#  '刘广才',
#  '杨进',
#  '张泽田',
#  '哈罗维兹',
#  '张大宁',
#  '陈超君',
#  '郑荣梁',
#  '王鸿',
#  '阮氏',
#  '张素我',
#  '马明捷',
#  '马西',
#  '胡熙明',
#  '武大伟',
#  '卡巴伊',
#  '侯殿禄',
#  '穆罕默德·侯赛因·马拉埃克',
#  '李承淑',
#  '尚占',
#  '王保俊',
#  '朱镕基',
#  '罗扬',
#  '郭裕怀',
#  '李玉光',
#  '巴尔舍夫斯基',
#  '张君瑞',
#  '王频',
#  '安德烈·科科申',
#  '王建华',
#  '成方圆',
#  '杨志望',
#  '刘儒庭',
#  '杨贵兰',
#  '羊盘初',
#  '陈建军',
#  '郑天翔',
#  '张发奎',
#  '李德洙',
#  '王玉柱',
#  '李遵英',
#  '周平',
#  '高惠娟',
#  '林春生',
#  '哈里·詹金斯',
#  '罗宏宇',
#  '廖汉生',
#  '加藤正夫',
#  '冯晓泉',
#  '吴华品',
#  '王尔山',
#  '西西',
#  '倪效武',
#  '李希（宏音）',
#  '盛国兰',
#  '佘健明',
#  '钟行',
#  '王智琼',
#  '阙端麟',
#  '孙星文',
#  '孔繁文',
#  '冯永祥',
#  '高瑞科',
#  '任随意',
#  '张紫云',
#  '庞增福',
#  ...}

# %%
entities['ns']
# Out:
# {'阿尔及利亚',
#  '瑞丽市',
#  '素可泰',
#  '珠江三角洲',
#  '排牙山',
#  '临川',
#  '比萨斜塔',
#  '伯尔萨',
#  '刘庄村',
#  '鄢家河',
#  '宋坑',
#  '临江',
#  '栾城县',
#  '孟加拉国',
#  '于洪区',
#  '苏丹',
#  '明尼苏达州',
#  '凹底镇',
#  '海淀剧场',
#  '汉城',
#  '牧奎村',
#  '杏花岭区',
#  '辛辛那提城',
#  '塞纳河畔',
#  '奥希金斯公园',
#  '白水镇',
#  '兰州',
#  '电器道',
#  '交道口',
#  '银川市',
#  '浦东新区',
#  '北大荒',
#  '醴陵',
#  '绥德',
#  '中央大街',
#  '潍坊市',
#  '北甸子乡',
#  '牡丹江',
#  '四川省凉山彝族自治州',
#  '夫子庙',
#  '苏北',
#  '钓鱼台国宾馆',
#  '得克萨斯州',
#  '安徽省',
#  '上海商城',
#  '宁连路',
#  '蒲圻市',
#  '衡南',
#  '万家寨',
#  '江西省宜春地区',
#  '北京海淀剧院',
#  '波兰',
#  '武邑黄口',
#  '呼和浩特',
#  '天津市',
#  '江津',
#  '沈泉庄',
#  '黑非洲',
#  '合肥',
#  '南美洲',
#  '河东',
#  '胶东',
#  '阿里高原',
#  '胶南市',
#  '大别山',
#  '北京光彩体育馆手球馆',
#  '莫桑比克',
#  '北京经济技术开发区',
#  '格拉茨',
#  '广东',
#  '晋豫',
#  '坦桑尼亚',
#  '阿比托',
#  '河北张家口地区',
#  '阜南县',
#  '宁波',
#  '达特茅思',
#  '北爱尔兰',
#  '池洞镇',
#  '九湖镇',
#  '砀山县',
#  '汕头',
#  '湄公河',
#  '凤凰岭',
#  '二里头',
#  '田阳县',
#  '巴西利亚',
#  '龙庆峡',
#  '天河体育场',
#  '蒙得维的亚',
#  '西花厅',
#  '南京路',
#  '南召',
#  '江西省',
#  '济南良友富临大酒店',
#  '芝加哥',
#  '内塔尼亚胡',
#  '长江三峡',
#  '黄粱梦镇',
#  '菲律宾',
#  '华尔街',
#  '昆仑山',
#  '长春沟村',
#  '揭阳',
#  '文化路',
#  '大宁河',
#  '马达加斯加',
#  '大观园',
#  '王家坝村',
#  '亚洲',
#  '延吉路',
#  '恩古巴尼',
#  '崂山区',
#  '筷子巷',
#  '虹口区',
#  '南斯拉夫联盟黑山共和国',
#  '台州',
#  '海南',
#  '许家坝区',
#  '新桥镇',
#  '银都大厦',
#  '兴化州',
#  '大涧村',
#  '交城县',
#  '山西省晋城市电视大演播厅',
#  '香港文化中心大剧院',
#  '台湾省',
#  '平顶山市',
#  '小马村',
#  '日本',
#  '（长）江',
#  '淄博市',
#  '地中海地区',
#  '新加坡',
#  '大连港',
#  '吉林市',
#  '北京当代商城',
#  '民乐乡',
#  '辛店镇',
#  '沂河',
#  '广州',
#  '中国科技馆',
#  '拉巴特',
#  '文锦渡',
#  '巴拿马',
#  '中信宁波国际大酒店',
#  '色庆乡',
#  '二宫乡',
#  '和田',
#  '孟加拉',
#  '唐古拉山',
#  '上海证券大厦',
#  '宁家坡',
#  '何坊村',
#  '纳雍',
#  '奥斯曼帝国',
#  '阿布哈兹自治共和国',
#  '普拉塔诺河',
#  '吉林省',
#  '涿州',
#  '美国纽约现代艺术博物馆',
#  '阿西西城',
#  '北京世纪剧院',
#  '波流固村',
#  '喀布尔',
#  '秦皇岛市',
#  '西藏拉萨贡嘎机场',
#  '阿里',
#  '扎龙',
#  '江苏省',
#  '迪庆机场',
#  '毛主席纪念堂',
#  '菏泽市',
#  '布加勒斯特市',
#  '波恩市',
#  '白沙',
#  '维拉猜',
#  '阿拉伯联合酋长国',
#  '巴塞罗那',
#  '西单',
#  '丁家山',
#  '五福涧村',
#  '沂蒙山区',
#  '邹城',
#  '沙坪坝',
#  '内蒙古草原',
#  '滁州',
#  '卡贝略港',
#  '安丘市',
#  '番禺市',
#  '阿姆斯特丹',
#  '八大处公园',
#  '柴达木盆地',
#  '临泽县',
#  '长城宾馆',
#  '安溪',
#  '大禾',
#  '澳大利亚',
#  '君士坦丁堡',
#  '沙特阿拉伯',
#  '盖茨堡镇',
#  '奎松地区',
#  '中国香港地区',
#  '瑞丽姐告镇',
#  '景泰',
#  '恩施',
#  '蒙巴萨',
#  '咸丰',
#  '吴兴',
#  '盐城滩涂自然保护区',
#  '红树区',
#  '平和县',
#  '仁川',
#  '西跨湖村',
#  '郴州',
#  '承德市',
#  '乔克西山口',
#  '浏阳市',
#  '塔克拉玛干',
#  '临海',
#  '慈江道',
#  '涿鹿县',
#  '泰顺',
#  '石山镇',
#  '西八道街',
#  '河南信阳地区',
#  '西城',
#  '日喀则地区',
#  '河北',
#  '东寨港',
#  '吉尔吉斯斯坦',
#  '吉达',
#  '杨村',
#  '陕西',
#  '黎巴嫩',
#  '西胡同村',
#  '大圪村',
#  '渤海',
#  '小港村',
#  '美洲',
#  '鹭岛',
#  '英国',
#  '宁河',
#  '镇江市',
#  '西西里',
#  '哥伦比亚',
#  '曲靖',
#  '萨吉德',
#  '滩堆',
#  '西城区',
#  '清水河',
#  '泗水',
#  '肥西县',
#  '巴林',
#  '朝鲜',
#  '碗厂乡',
#  '高都镇',
#  '东段',
#  '叙利亚',
#  '福兴寺',
#  '襄曲',
#  '上海灯具城',
#  '瓦店镇',
#  '华盛顿',
#  '洪湖市',
#  '贵定',
#  '上饶',
#  '民航成都双流机场',
#  '呼伦贝尔',
#  '东平县',
#  '长安街',
#  '墨西哥湾',
#  '天祝',
#  '宜昌县',
#  '辉耀乡',
#  '象角村',
#  '西村',
#  '巴库',
#  '清迈',
#  '济阳',
#  '中国张家口地区',
#  '洛美',
#  '国家体委中国乒乓球队训练馆',
#  '塔里木盆地',
#  '汕头市',
#  '海南省乐东黎族自治县',
#  '日喀则',
#  '青山苗族乡',
#  '都镇湾镇',
#  '石头城',
#  '刚果共和国',
#  '上海博物馆',
#  '天安门',
#  '马耳他共和国',
#  '新良庄',
#  '沈阳市动物园',
#  '阳朔县',
#  '蒙古',
#  '库尔德',
#  '欧洲地区',
#  '烟台',
#  '陕西商洛地区',
#  '小浪底',
#  '湖南',
#  '普卡拉姆',
#  '科伦坡',
#  '西安妇女儿童活动中心',
#  '连介',
#  '前元庄',
#  '贝宁',
#  '西藏',
#  '吴淞口',
#  '内蒙古自治区',
#  '景山',
#  '渭北',
#  '象山',
#  '高雄',
#  '沈阳军区八一体育馆',
#  '南京中共代表团梅园新村纪念馆',
#  '嘉定县',
#  '日本关东甲信地区',
#  '台北县',
#  '都江堰',
#  '百慕大',
#  '柳州',
#  '海流图乡',
#  '柳堡',
#  '卢沟桥',
#  '辽阳',
#  '藏经洞',
#  '罗勇',
#  '渤海湾',
#  '东海县',
#  '竹山县',
#  '山南镇',
#  '宁乡县',
#  '修武县',
#  '富宁县',
#  '聂荣县',
#  '格但斯克',
#  '钦州港',
#  '锡山市',
#  '圣地亚哥省',
#  '民昌果园',
#  '郑南',
#  '永安镇',
#  '翠屏峰',
#  '得州',
#  '滑县',
#  '津巴布韦',
#  '永隆乡',
#  '温州',
#  '巴西',
#  '西青区',
#  '布宜诺斯艾利斯',
#  '西辛庄村',
#  '巴黎圣母院',
#  '薛庄村',
#  '香榭丽舍',
#  '天河养殖场',
#  '丹寨县',
#  '北京路',
#  '加拉加斯',
#  '怀远县',
#  '青浦',
#  '沁水',
#  '加那利',
#  '毛家湾',
#  '余姚市',
#  '豫南平原',
#  '乌克兰',
#  '松辽',
#  '耶城',
#  '南市区',
#  '肇庆',
#  '营市',
#  '李宁牌专卖店',
#  '塔兰托市',
#  '智利火地岛',
#  '北京德宝饭店',
#  '东湖',
#  '阿北乡',
#  '宣汉县',
#  '艾哈迈迪亚',
#  '正阳县',
#  '百老汇',
#  '罗布泊湖',
#  '天津艺术博物馆',
#  '阿尔法镇',
#  '特拉维夫',
#  '双桥区',
#  '厦门',
#  '吉布提',
#  '贾鲁河',
#  '厦门市',
#  '阿克莫拉',
#  '当阳',
#  '七坊镇',
#  '孙桥',
#  '花明楼镇',
#  '丹东市',
#  '八宝山革命公墓',
#  '科普特教区',
#  '黑海',
#  '瞿家村',
#  '孙桥现代农业园区',
#  '淮海路',
#  '扎达县',
#  '沁源',
#  '滨海',
#  '鄂州市',
#  '大庄矿',
#  '鞍山',
#  '万里长城',
#  '旱垣地区',
#  '蓬莱',
#  '迭部县',
#  '洪泽县',
#  '常州港',
#  '东平湖',
#  '蓝色清真寺',
#  '梅克伦堡州',
#  '巴伐利亚州',
#  '塞北',
#  '里加',
#  '燕麦地组',
#  '聂当卓玛拉康寺',
#  '安康',
#  '因巴巴区',
#  '北非洲',
#  '山耳东村',
#  '中条山地区',
#  '华东',
#  '新郑市',
#  '基特加',
#  '索马里',
#  '青山堡村',
#  '维多利亚',
#  '忻州地区',
#  '费县',
#  '南新路',
#  '罗庄镇',
#  '波罗的海地区',
#  '乍浦港',
#  '圣何塞地区',
#  '东南亚',
#  '伊斯兰堡',
#  '马尔维纳斯',
#  '伊克昭盟',
#  '咸阳市',
#  '北京朝阳体育馆',
#  '奥斯马奇地区',
#  '辽东湾',
#  '双龙镇',
#  '约翰内斯堡',
#  '阿拉伯地区',
#  '李沧区',
#  '火地岛',
#  '高平市',
#  '南丰祠',
#  '京山',
#  '库斯科省',
#  '阿尔及利亚民主人民共和国',
#  '帝王大厦',
#  '阳朝乡',
#  '呼兰河域',
#  '临泉县',
#  '厄加勒斯角',
#  '包头市',
#  '大石桥市',
#  '淮河',
#  '波恩',
#  '沂蒙',
#  '乌干达',
#  '巴蜀',
#  '法国圣艾蒂安市动物园',
#  '闻喜县',
#  '保坪乡',
#  '赤县',
#  '邱少云纪念馆',
#  '沙家浜',
#  '雁荡',
#  '石头寨车站',
#  '东非',
#  '虎林市',
#  '上海新龙华站',
#  '香港维多利亚公园',
#  '徐汇',
#  '灵隐寺',
#  '青山冲',
#  '长安',
#  '意大利',
#  '江苏淮安新华书店',
#  '日内瓦',
#  '楼山乡',
#  '延庆县',
#  '离石市',
#  '阿比让市',
#  '经五路',
#  '微山湖',
#  '金沙江',
#  '北大仓',
#  '苏州市',
#  '梭落坪村',
#  '高州',
#  '希腊',
#  '谷饶镇',
#  '格拉斯哥',
#  '六里桥商场',
#  '湖塘镇',
#  '洋洲村',
#  '切尔西',
#  '麦地那',
#  '米兰',
#  '珠江',
#  '英吉利海峡',
#  '虹桥',
#  '北岳区',
#  '浮山',
#  '阿什哈巴德',
#  '广昌',
#  '土库曼斯坦',
#  '河北省张家口地区',
#  '翠亨',
#  '中欧',
#  '石嘴村',
#  '南京石林商场',
#  '多瑙河',
#  '临澧',
#  '虹口公园',
#  '摆勺',
#  '遵化市',
#  '关山',
#  '塔河',
#  '白沙黎族自治县',
#  '贵州省',
#  '谷城县',
#  '西峡县',
#  '苍山',
#  '十字街村',
#  '炎黄艺术馆',
#  '山东省',
#  '日照县',
#  '平遥',
#  '瓜那雷斯',
#  '北京中国美术馆',
#  '比陀瑞尔斯大街',
#  '鄢家河村',
#  '白鹿原',
#  '大兴县北普陀影视城',
#  '安曼市',
#  '庄河',
#  '黄浦',
#  '吉祥寺',
#  '罗山',
#  '广安门',
#  '那务镇',
#  '新界埠乡',
#  '开罗阿盟大街',
#  '下三交镇',
#  '武义县',
#  '长野',
#  '福州工艺美术博物馆',
#  '八达岭',
#  '江西上饶地区',
#  '凤凰县木江坪乡塘公索苗寨',
#  '阿拉木图',
#  '永兴岛',
#  '宣武区',
#  '黑龙港流域',
#  '左家庄小区',
#  '韶山路',
#  '新兴村',
#  '孙家庄乡',
#  '奎塔',
#  '青浦县',
#  '丰台区',
#  '（黄）河',
#  '斯德哥尔摩市',
#  '天津港',
#  '太岳根据地',
#  '沙溪',
#  '香山',
#  '马塞马拉平原',
#  '奇迹广场',
#  '安达卢西亚',
#  '大丰港',
#  '左云',
#  '日切村',
#  '奉化',
#  '金寨县',
#  '玉溪市',
#  '源东乡',
#  '新疆自治区',
#  '新罗西斯克港',
#  '亚运村',
#  '河西镇',
#  '墨西哥',
#  '洛桑',
#  '中国香港特别行政区',
#  '乌拉圭',
#  '琼山',
#  '大亚湾',
#  '黎平',
#  '河西村',
#  '河西',
#  '雷利赞',
#  '新塘',
#  '津城',
#  '宁城',
#  '丰县',
#  '营口市',
#  '垣曲县',
#  '白云山云台花园',
#  '伊斯坦布尔',
#  '圣特莱萨',
#  '贝鲁特',
#  '缅甸',
#  '宝应',
#  '吕梁地区',
#  '成都市动物园',
#  '太平洋',
#  '泉林',
#  '程林庄',
#  '富源县',
#  '云岭乡',
#  '郑州',
#  '石家庄市',
#  '京城',
#  '重庆',
#  '海南省白沙黎族自治县',
#  '鄂温克旗',
#  '东方',
#  '中国现代文学馆',
#  '上辛口乡',
#  '固县',
#  '中庄乡',
#  '堪培拉',
#  '佛蒙特州',
#  '西单商场',
#  '九江市',
#  '金湖县',
#  '晋安沟',
#  '云南',
#  '泽村',
#  '峒中',
#  '邛崃',
#  '铜仁',
#  '河西区',
#  '北京新东安市场',
#  '小界岭',
#  '南美',
#  '洛渍岔',
#  '黄县',
#  '琉璃厂',
#  '山形县',
#  '牡丹乡',
#  '伊斯兰',
#  '合江县',
#  '乌兰牧旗',
#  '长丰县',
#  '赵集乡',
#  '路易港',
#  '伊朗',
#  '保加利亚',
#  '南千岛群岛',
#  '本溪市',
#  '松桃',
#  '东平',
#  '北戴河',
#  '保国乡',
#  '浦北县',
#  '黄石市',
#  '杨花台村',
#  '诺福克郡',
#  '雅加达',
#  '武汉',
#  '中国南极长城站',
#  '长沙市五一路芙蓉宾馆',
#  '青海省',
#  '比利时',
#  '张北',
#  '黄骅市',
#  '京西宾馆',
#  '燕山',
#  '河北地区',
#  '休斯敦',
#  '旁遮普',
#  '舟山',
#  '阎三囤',
#  '格拉茨市',
#  '运河饭店',
#  '黄岩',
#  '离石',
#  '红雁池',
#  '北京城建集团二公司一分公司通产工地',
#  '富港村',
#  '汨罗市',
#  '广东体育场',
#  '中山',
#  '大南沟',
#  '掖县',
#  '长城',
#  '牛城',
#  '长湖',
#  '费加罗',
#  '石门岩',
#  '威舍镇',
#  '卢浮宫',
#  '绥远',
#  '珍珠港',
#  '尖沙咀',
#  '北京百鸟园',
#  '汉堡音乐厅',
#  '桃溪镇',
#  '达瓦卡',
#  '宽城街',
#  '人民大会堂',
#  '苏南地区',
#  '安西',
#  '龙岩坡',
#  '厄瓜多尔',
#  '蜀山',
#  '悉尼城',
#  '德钦地区',
#  '科威特市',
#  '南山区',
#  '红花村',
#  '慈母村',
#  '汶阳镇',
#  '杭州',
#  '爱沙尼亚',
#  '海口',
#  '圣路易斯市',
#  '巢湖',
#  '西方',
#  '贝尔格莱德',
#  '那曲地区双湖特别行政区',
#  '大渡河大桥',
#  '西峡',
#  '湘西',
#  '牟平区',
#  '圣马力诺',
#  '蒙特卡洛',
#  '上海站',
#  '九所',
#  '明湖',
#  '林口县',
#  '克维特绥',
#  '中国美术馆',
#  '布里斯班市',
#  '王家村',
#  '加布罗沃',
#  '撒哈拉沙漠',
#  '金华县',
#  '河北邢台中桥商场',
#  '非洲地区',
#  '达累斯萨拉姆',
#  '文莱',
#  '南京',
#  '台湾地区',
#  '广东省汕头经济特区',
#  '下庵',
#  '沅水',
#  '荷兰',
#  '魏县',
#  '广水',
#  '鲁西',
#  '尼日尔',
#  '攀枝花',
#  '唐海县',
#  '隆回',
#  '和县',
#  '宜阳县',
#  '北京第四清洁车辆场',
#  '呼和浩特白塔机场',
#  '华沙',
#  '达荷美共和国',
#  '科巴农场',
#  '王家棚',
#  '殷墟',
#  '北高加索地区',
#  '乐山',
#  '北京',
#  '中山站',
#  '农林下路',
#  '牟家村',
#  '阿塞拜疆',
#  '太原市',
#  '菏泽地区',
#  '六盘水',
#  '罗湖',
#  '本·赛卡角',
#  '雅典',
#  '西藏那曲地区',
#  '挪威',
#  '伊拉克',
#  '五一路',
#  '寒山寺',
#  '慈江道地区',
#  '摩尔多瓦',
#  '米花岭',
#  '大石坝',
#  '保靖',
#  '杏五区',
#  '闵行区',
#  '关东',
#  '恩施州',
#  '衡水市',
#  '圣彼得堡',
#  '首都博物馆',
#  '西安博物馆',
#  '古蔺县',
#  '咸阳',
#  '雅砻江',
#  '中南海',
#  '十二圩镇',
#  '峡江',
#  '巫山',
#  '解放路',
#  '湘江',
#  '呼伦贝尔盟',
#  '阿塔科拉省',
#  '焦作',
#  '比格尔海峡',
#  '昌平',
#  '济南站',
#  '黄浦江畔',
#  '开封市',
#  '拉卜楞寺',
#  '中南海紫光阁',
#  '古城镇',
#  '外高桥',
#  '洋坪',
#  '金口河区',
#  '南油',
#  '香港岛',
#  '河内',
#  '利马',
#  '泸州市',
#  '黄南藏族自治州',
#  '龙潭',
#  '惠安县',
#  '龙城',
#  '顺德市',
#  '栾老',
#  '昌都',
#  '安第斯',
#  '石洞源村',
#  '新疆银都大厦',
#  '中条山',
#  '德州',
#  '清莱',
#  '彰武县',
#  '哈密',
#  '河南',
#  '安顺',
#  '古丈县',
#  '临县',
#  '淮河流域',
#  '临泽',
#  '苏门达腊岛',
#  '洪泽湖',
#  '拉萨市',
#  '大同市',
#  '巴伦支海地区',
#  '长城饭店',
#  '无锡',
#  '淮安市',
#  '道外区',
#  '茅山',
#  '信宜',
#  '火地岛省',
#  '俄罗斯',
#  '黑龙江省',
#  '古镇村',
#  '临漳',
#  '萨摩亚',
#  '巩固村',
#  '栾城',
#  '恩施市',
#  '莱索托',
#  '武汉市',
#  '新平镇太平村',
#  '普尔尼亚奇科',
#  '两路镇',
#  '万隆',
#  '宁都县',
#  '东村',
#  '卢克索',
#  '丰润县',
#  '南泥湾',
#  '延吉',
#  '务川',
#  '黄浦区',
#  '江南',
#  '西班牙',
#  '矮寨镇',
#  '吐鲁番',
#  '清丰县',
#  '隆丰镇',
#  '广州天河高新技术开发区',
#  '长武县',
#  '陶然亭',
#  '镇江',
#  '石河子',
#  '尼泊尔',
#  '深州',
#  '大阪市',
#  '中国丝绸博物馆',
#  '科巴县',
#  '大安乡',
#  '阿比让',
#  '莱茵',
#  '科托尔湾',
#  '九屋乡',
#  '曼苏里',
#  '万洲',
#  '碣石',
#  '北京圆山大酒店',
#  '非洲',
#  '九狮苑',
#  '南斯拉夫',
#  '新化',
#  '通产大厦',
#  '拉斯韦加斯城',
#  '西宁',
#  '西安',
#  '衡南县',
#  '波尔多',
#  '浦东中央公园',
#  '馆陶',
#  '西昌',
#  '马德里',
#  '普吉',
#  '北极',
#  '和平车站',
#  '石南地区',
#  '洞井镇',
#  '鹤山市',
#  '罗布林卡',
#  '泾县',
#  '玉林',
#  '娄烦县',
#  '临沂',
#  '电孕乡',
#  '湘潭县',
#  '苏南',
#  '眉山县',
#  '漳平',
#  '北海',
#  '多伦多',
#  '淮海',
#  '峡山',
#  '川西平原',
#  '落耳坡村',
#  '张家港市',
#  '那曲地区',
#  '岳阳市',
#  '娘子关镇',
#  '万象',
#  '南清园',
#  '唐宁街首相府',
#  '墨西哥城',
#  '罗布泊地区',
#  '新界',
#  '宣和镇',
#  '广汉市',
#  '七里河',
#  '青岛市',
#  '运河区',
#  '共和',
#  '龙汇庄园',
#  '天水围',
#  '大兴安岭',
#  '抗日战争纪念馆',
#  '利勒哈默尔',
#  '上海市',
#  '南苑乡',
#  '羊三木',
#  '嘉黎县',
#  '同心县',
#  '北京故宫',
#  '黄岛',
#  '西关村',
#  '明斯克',
#  '八角田',
#  '花乡',
#  '易县',
#  '小龙坎',
#  '阿根廷',
#  '东耶路撒冷',
#  '夔门',
#  '人民剧场',
#  '惠州市',
#  '陆家嘴金融贸易区',
#  '乌盟察右中旗辉腾锡勒地区',
#  '国贸饭店',
#  '抚顺',
#  '酒泉',
#  ...}

# %%
entities['nt']
# Out:
# {'共青团云南省委',
#  '上海市房屋土地管理局',
#  '中国认证人员国家注册委员会环境管理专业委员会',
#  '格威特体育用品公司',
#  '荆州轻桥股份有限公司',
#  '老挝人民革命党',
#  '项桥电管站',
#  '远东研究所',
#  '鹤壁市电视台',
#  '塔斯社',
#  '方城县公安局法医院',
#  '福建省福州市新华书店',
#  '黎政府',
#  '上海科学普及出版社',
#  '新加坡国际金融交易所',
#  '河南财经学院',
#  '小浪底建管局',
#  '台湾大学',
#  '国商集团',
#  '中国奥林匹克委员会',
#  '南昌郊区区委',
#  '那曲军分区',
#  '新疆电力工业局',
#  '中共四川省委',
#  '成都市经委',
#  '上海东方队',
#  '北京市首都规划设计委员会',
#  '南通仙羽制衣有限公司',
#  '东滩煤矿',
#  '中央美院',
#  '世界银行',
#  '五虎岭小学',
#  '上海滑稽剧团',
#  '联邦邮电部',
#  '美国国际集团亚洲投资有限公司',
#  '中国青少年研究中心少年儿童研究所',
#  '松下电工·万宝电器（广州）有限公司',
#  '重庆有线电视台',
#  '龙舟股份',
#  '茅盾文学奖评奖委员会',
#  '对外友协',
#  '中国诚信证券评估公司',
#  '土宪法法院',
#  '北海道拓殖银行',
#  '美联社',
#  '四川蓝剑队',
#  '国务院军队转业干部安置工作小组',
#  '石油部',
#  '国家体委体操运动管理中心',
#  '伦敦帝国理工学院',
#  '东四街道办事处',
#  '瑞士圣加仑修道院',
#  '哈萨克阿里法拉比国立大学',
#  '美国志愿者协会',
#  '抗敌演剧队',
#  '鲁北化工',
#  '北京人民日报教科文部文化组',
#  '南方局',
#  '北京艺术研究所',
#  '江苏悦达公司盐城汽车厂',
#  '山东省鄄城县公安局巡警大队',
#  '西南财经大学',
#  '国家旅游局',
#  '瑞典沃尔沃公司',
#  '北爱民主党',
#  '河西医院',
#  '衡阳市支队后勤处',
#  '西藏自治区科委农牧处',
#  '北京市外来劳动力职业介绍中心',
#  '尼加拉瓜桑地诺民族解放阵线',
#  '农业银行四川省西昌市支行',
#  '香港福建社团联会',
#  '中共中央西北局',
#  '解放军艺术学院影视中心',
#  '中国书法家协会',
#  '广东天贸南方大厦百货有限公司',
#  '全国人大华侨委员会',
#  '济南铁路分局',
#  '江苏文化艺术发展基金会',
#  '法国军事学校',
#  '北京市技术监督局',
#  '中国基建控股公司',
#  '沈阳杂技团',
#  '沈阳三生公司',
#  '天津绿天使公司',
#  '英国皇家空军',
#  '俄罗斯联邦边防局',
#  '深圳万德莱通讯有限公司',
#  '解放军南京军区１０２医院',
#  '八路军驻重庆办事处',
#  '晋城市城区区委',
#  '安徽铜陵有色金属（集团）公司第一冶炼厂',
#  '北京新东安集团',
#  '昆明军区',
#  '山西省第三区专员公署',
#  '北京市百货大楼党委',
#  '中国人民解放军空军',
#  '山东省淄博市公安局淄川分局昆仑派出所',
#  '四川省泸州医学院附属医院',
#  '锦江集团',
#  '深圳市年玉田贸易有限公司',
#  '辽宁女篮',
#  '公主岭市怀德粮库',
#  '荷兰国防部',
#  '武警山西总队',
#  '湖南省军区吉首军分区',
#  '印尼政府',
#  '中国新星石油公司',
#  '中央社会主义学院科社教研室',
#  '利比亚能源部',
#  '河北省高邑县委',
#  '中国电影导演协会',
#  '外交部',
#  '大连京剧团',
#  '越南人民军',
#  '巴国民议会',
#  '武警湖南总队衡阳市支队',
#  '人民美术出版社',
#  '中国对外贸易经济合作部',
#  '江苏加佳队',
#  '美国国会参议院',
#  '全国人大常委会',
#  '临安锦城小学',
#  '西藏自治区第二人民医院妇产科',
#  '绿色和平组织',
#  '西班牙工人社会党',
#  '香港特别行政区临时立法会',
#  '地质队后方基地',
#  '华东野战军第八兵团后勤部宣传科',
#  '中国道教协会',
#  '北京海燕优美加体育器材有限公司',
#  '中国国民党革命委员会',
#  '印度尼西亚国际银行',
#  '贝尔公司',
#  '湖北车桥公司',
#  '国商银行',
#  '中科院微生物研究所',
#  '中国中央音乐学院',
#  '北京阿凡提文化艺术有限公司',
#  '健力宝青年队',
#  '政协第九届全国委员会',
#  '陕北特委',
#  '广电部电影局',
#  '军委纪委',
#  '华南缝制设备集团公司',
#  '中国马克思主义哲学史学会',
#  '交通部',
#  '英国议会',
#  '台湾顶新集团公司',
#  '北京医科大学神经科学研究所',
#  '中央电视台军事部',
#  '青海省平弦实验剧团',
#  '上海交通大学',
#  '河北省邱县县委',
#  '重庆市长寿县望江路石油采气五队',
#  '大连开发区',
#  '成飞公司',
#  '中国奥委会',
#  '广东爱多电器公司',
#  '中国版权研究会',
#  '八路军三八六旅',
#  '英国皇家海军学院',
#  '夏普公司',
#  '华北人民革命大学',
#  '昆明机床',
#  '鸿宇中学',
#  '北京电视台',
#  '河北省人大',
#  '广东省番禺市沙湾镇骏业有限公司',
#  '中条山有色金属公司',
#  '民政部',
#  '美国加州斯克里普斯研究所',
#  '解放军第四六○医院',
#  '北京军区',
#  '北京商业管理干部学院',
#  '华北石油采油三厂',
#  '老挝和平与团结委员会',
#  '日本商业银行',
#  '国内贸易部',
#  '成都发动机公司',
#  '解放军总后勤部',
#  '宏业集团',
#  '北京宏景文化传播公司',
#  '铁道部京九文化列车艺术团',
#  '利库德集团',
#  '中日合资华糖洋华堂商业有限公司',
#  '河南美术出版社',
#  '深圳交通监控中心',
#  '中国游艺机联合公司',
#  '德彪中国癌症研究基金会',
#  '中国基督教三自爱国运动委员会',
#  '美国哥伦比亚大学',
#  '塞尔维亚民主党',
#  '郑州市中原区人民法院行政审判庭',
#  '江苏兴化棉纺织厂办公室',
#  '中国版权保护中心',
#  '西安临潼邮票公司',
#  '中国核工业总公司',
#  '海南省海盛船务实业股份有限公司',
#  '湖北省总工会',
#  '中共广东区委军事部',
#  '邯郸钢铁公司',
#  '大庆石油化工总厂',
#  '南斯拉夫队',
#  '广东省公安边防总队党委',
#  '中国国际战略研究基金会',
#  '上海六百实业公司',
#  '桂光制衣厂',
#  '利民药厂',
#  '本钢板材股份有限公司',
#  '俄远东研究所文学艺术组',
#  '朝阳区青少年活动中心',
#  '黄浦职业服务管理中心',
#  '晋察冀分局',
#  '中共党史出版社',
#  '安徽合力股份有限公司',
#  '交口县五磷有限公司',
#  '华玉公司',
#  '中共中央统战部',
#  '美国联邦通信委员会',
#  '伊拉克驻约旦大使馆',
#  '清华大学经济管理学院',
#  '北京市崇文公安分局',
#  '柳州市委',
#  '郑州铁路分局月山机务段',
#  '江苏省省委',
#  '泰国文官委员会',
#  '四川音乐学院',
#  '联合国第三委员会',
#  '河南省科技开发交流中心科普部',
#  '桂光公司',
#  '第四军医大学',
#  '海南省定安县龙门镇三九小学',
#  '尚朋堂股份有限公司',
#  '北京建工集团总公司',
#  '张家港港务局',
#  '中国企业管理协会',
#  '第二军医大学东方肝胆外科医院',
#  '英国驻华使馆文化教育处',
#  '浦东钢铁（集团）公司',
#  '东京经济大学',
#  '环球体育影业公司',
#  '卫生部',
#  '武汉克林清洗工程有限公司',
#  '亚世达集团',
#  '五台中队',
#  '贵州省松桃苗族自治县格老村完全小学',
#  '山东石油公司邹城分公司',
#  '古吴轩出版社',
#  '中共四川省纪委',
#  '文化部艺术家联谊会',
#  '伊拉姆人民民主党',
#  '大亚湾核电站',
#  '武汉市工商局',
#  '纽约中国银行',
#  '山东省中医药研究所',
#  '乌鲁木齐市委',
#  '俄政府独联体事务部',
#  '俄中央银行',
#  '沈阳军区司令部',
#  '德国邮电部',
#  '中国环境管理体系认证指导委员会',
#  '北京海燕—优美加体育器材有限公司',
#  '城市商业银行',
#  '维也纳利奥波德基金会',
#  '北京西单友谊集团',
#  '海南神龙股份有限公司',
#  '国家核安全局',
#  '黑龙江省省外办',
#  '日本国会',
#  '中国社科院社会学所',
#  '朝阳区青联',
#  '北海道拓殖银行东京分社',
#  '河南许昌市人民广播电台',
#  '河南省妇联',
#  '上海译文出版社',
#  '太谷纺织厂',
#  '中国乒乓球协会',
#  '河北会友线缆集团',
#  '加拿大滑铁卢大学',
#  '阿尔巴尼亚人民议会',
#  '北京市新闻出版局',
#  '财政部商贸司',
#  '广西壮族自治区人民医院',
#  '扬州木偶剧团',
#  '中共中央东北局',
#  '中央纪委信访室',
#  '空军二十一厂',
#  '克虏伯蒂森不锈钢有限公司',
#  '山西省太原市农科所',
#  '日本伊藤洋华堂',
#  '郑州煤炭学院',
#  '日本队',
#  '华星集团',
#  '武警部队国旗护卫队',
#  '南昌市委',
#  '俄新社',
#  '江铃汽车股份有限公司',
#  '中国排球协会',
#  '武汉杂技团',
#  '以政府',
#  '内蒙古军区',
#  '中国致公党',
#  '京郊门头沟区潭柘寺镇政府',
#  '北京市怀柔县妇联',
#  '浙江省金华市大世界商厦党总支',
#  '上海实业公司',
#  '欧洲委员会',
#  '电子部情报所',
#  '宜昌大学',
#  '中国科学院软件研究所',
#  '马耳他政府',
#  '国家档案局',
#  '江苏艺龙集团',
#  '武警北京一总队十支队',
#  '上海医科大学附属中山医院',
#  '中国共产党第十五次全国代表大会',
#  '西安海星公司',
#  '上海新卫塑料制品厂',
#  '中国行政管理学会',
#  '青海省佛教协会',
#  '青海省湟中县科技局',
#  '香港队',
#  '广东省兽医防疫检疫站',
#  '同创产业信息集团',
#  '交通银行',
#  '伊拉克驻约旦使馆',
#  '随州一医院',
#  '山东农业大学',
#  '韩国住宅银行',
#  '俄总统新闻局',
#  '百富勤投资集团有限公司',
#  '亚洲蒂亚拉银行',
#  '山东兖州矿业集团公司党委',
#  '上海电影制片厂',
#  '伊化集团公司',
#  '耶鲁大学',
#  '北京九千标准质量体系认证中心',
#  '常德鼎城一中',
#  '安徽省机械厅',
#  '华南农业大学',
#  '西方７国集团',
#  '武警湖北总队党委',
#  '中华医学会北京分会',
#  '辽宁男排',
#  '北京铁路公安处',
#  '山形电视台',
#  '巴西队',
#  '泰国工业部',
#  '广东神州燃气用具有限公司',
#  '河北省抗震救灾指挥部',
#  '中国人民政治协商会议第九届全国委员会',
#  '意大利政府',
#  '建设集团股份公司',
#  '中央电台',
#  '中国扶贫委员会',
#  '宁夏回族自治区银川市第二人民医院',
#  '盖城合唱团',
#  '中直机关工会联合会',
#  '拉哈纳信银行',
#  '宜昌市政协',
#  '无锡轻工大学',
#  '中央党校',
#  '北京大学物理系',
#  '建筑五金二厂党支部',
#  '湖北省实验豫剧团',
#  '韩国政府',
#  '广州福寿仙保健品厂',
#  '津巴布韦队',
#  '普乐普公共关系策划有限公司',
#  '林业局花卉公司',
#  '左翼剧联',
#  '语丝杂志社',
#  '杭州市政府',
#  '山东青州市工商局',
#  '华东空军机务处',
#  '二炮文工团',
#  '河北医科大学第三附属医院医疗队',
#  '国家开发银行',
#  '拉齐奥队',
#  '农业部市场信息司',
#  '天津市师范大学中文系',
#  '中国花样游泳队',
#  '中国农村杂志社',
#  '中国贸促会',
#  '广西壮族自治区科委社会发展与科学普及处',
#  '辽宁省阜新图书馆',
#  '世达电脑科技公司',
#  '湖南省国际信托投资公司',
#  '中国第二重型机械集团公司',
#  '约旦工程师协会',
#  '浙江省临安市气象局',
#  '安徽叉车集团',
#  '许昌市委',
#  '中国地质大学',
#  '福建省人大常委会',
#  '北京首钢队',
#  '吉林省人大常委会',
#  '中国油画学会',
#  '五台县化肥厂',
#  '澳门中华总商会',
#  '时代华纳公司',
#  '中国大使馆',
#  '俄国家杜马地缘政治委员会',
#  '深圳万德莱公司',
#  '大和银行',
#  '国家情报局',
#  '海燕公司',
#  '实达集团',
#  '北师大二部马特洛索夫班',
#  '济南明水利民制药厂',
#  '武汉湖北省军区招待所',
#  '河南省鄢陵县豫剧团',
#  '西南贝尔',
#  '高棉民族党',
#  '国务院学位办',
#  '重庆市电影公司送电影下乡流动放映队',
#  '南京大学',
#  '冶金部',
#  '先科公司',
#  '澳大利亚工党',
#  '葛朗台俱乐部',
#  '武汉市防汛指挥部',
#  '六机部科教组',
#  '江西省军区',
#  '甘肃工行',
#  '中国农学会科普部',
#  '广州五羊自行车企业集团公司',
#  '张家口探矿机械厂',
#  '国家计委科技司',
#  '广东核电投资公司',
#  '深圳市华为技术有限公司',
#  '北京高级人民法院',
#  '大宇重工',
#  '日本大和银行纽约分行',
#  '中央政法委',
#  '甘肃省曲艺团',
#  '内蒙古伊利实业集团股份有限公司',
#  '政协湖南省第八届委员会',
#  '铁一局五处秦岭公司',
#  '中国国旅总社',
#  '深圳机场集团公司',
#  '上海广电凯歌雷达通讯设备厂',
#  '中国剧协书记处',
#  '辽宁队',
#  '开元区人民法院',
#  '幸福工程组委会',
#  '中国电影评论学会',
#  '浙江中欣队',
#  '南京中华中学',
#  '北方分局',
#  '全国电码电话数据中心',
#  '内政部',
#  '山东电影制片厂',
#  '周小燕少年合唱团',
#  '江西南丰县一中',
#  '中国足协',
#  '文化部艺术局',
#  '国务院扶贫办',
#  '西非开发银行',
#  '北京市物资局',
#  '鹤山市委',
#  '岳南地委',
#  '全国扫黄工作小组办公室',
#  '联合国',
#  '大连艺术研究所',
#  '美国乒乓球队',
#  '广东省广州市委宣传部',
#  '石山派出所',
#  '北京地坛小学',
#  '大众公司',
#  '国际田径联合会',
#  '北京市设备安装工程公司',
#  '宜昌市福利院',
#  '中国农科院',
#  '亚马孙钢铁集团公司',
#  '德黑兰大学',
#  '俄罗斯国家杜马国防委员会',
#  '新疆医学院附属肿瘤医院',
#  '中国图书评论学会',
#  '中国民航',
#  '威斯敏斯特医院',
#  '中央军委纪委',
#  '中国外轮代理总公司',
#  '联合国发展署',
#  '上海中南大药房',
#  '以电视台',
#  '四川省人民政府',
#  '东京地方检察院',
#  '共青团宜昌市委',
#  '团中央',
#  '青海省委宣传部',
#  '山东省无棣县国税局',
#  '榆次电缆厂',
#  '香港普通话台',
#  '俄外交部',
#  '加拿大联邦政府',
#  '城建二公司团委',
#  '皇岗海关',
#  '宁波华茂集团',
#  '中央文史研究馆',
#  '全国记协',
#  '中国业余舞蹈竞技协会',
#  '北京市体育总会',
#  '中国男排',
#  '中国人保（集团）公司',
#  '国家旅游协会',
#  '冶金工业部洛阳耐火材料研究院',
#  '河南交通事故伤残鉴定中心',
#  '四川省轻工业品进出口公司',
#  '西昌卫星发射中心',
#  '中国跳水队',
#  '上航总调度室',
#  '广州市妇联',
#  '人大附中队',
#  '云南玉溪卷烟厂',
#  '美国图书馆协会',
#  '北京市外文书店',
#  '船舶总公司',
#  '中新技术开发有限公司',
#  '经贸合作分委会',
#  '解放军队',
#  '新疆人民会堂',
#  '世贸组织',
#  '古巴全国人大',
#  '天津北辰区实验小学',
#  '鲁艺烽火剧团',
#  '广东核电合营有限公司',
#  '香港建筑署职员会',
#  '四十五中学队',
#  '大同三医院',
#  '世纪演出公司',
#  '中策制药',
#  '美国朗讯科技公司',
#  '单晶河村党支部',
#  '中国海洋石油总公司',
#  '北京实宝来公司',
#  '阿迪达斯体育用品公司',
#  '陕西师范大学',
#  '中共太岳特委',
#  '秦皇岛交警支队车管所',
#  '青岛乳胶厂',
#  '上海航空公司',
#  '俄罗斯中央银行',
#  '中国社科院历史研究所',
#  '苏联队',
#  '江苏省歌舞剧院',
#  '云南省委宣传部宣传教育处',
#  '中国水产科学院黑龙江水产研究所',
#  '江苏省供销社',
#  '厦门市开元区人民法院',
#  '缅甸财金队',
#  '长城集团',
#  '北京市五十五中学',
#  '有色金属工业总公司',
#  '英国国防部',
#  '大杨集团',
#  '北平教育部',
#  '玉环县制动器厂',
#  '诺丁汉城市医院儿科',
#  '太原市市政工程设计研究院',
#  '美国亚洲基金会',
#  '国防科工委',
#  '上海远东出版社',
#  '泰国队',
#  '中国长江航运（集团）总公司客运处',
#  '中国人民解放军总参谋部',
#  '中华全国工商业联合会',
#  '国家安全部',
#  '北京安易电脑会计公司',
#  '大藏省金融检查部',
#  '临沂造纸厂',
#  '明州政府',
#  '大连陆军学院',
#  '湘潭大学团委',
#  '重庆百货大楼股份有限公司',
#  'ＴＣＬ通信设备股份有限公司',
#  '世界旅游组织',
#  '青岛港务局',
#  '美军太平洋总部',
#  '海南省琼剧院',
#  '中共晋冀豫省委统战部',
#  '外经贸部发展司',
#  '比利时室内乐团',
#  '重庆市农业科学研究所',
#  '广西壮族自治区南宁市财政局',
#  '山西省曲艺团',
#  '绿冷集团',
#  '香港特区临立会',
#  '天津市教育卫生委员会',
#  '微软公司',
#  '欧洲黑社会',
#  '中国航空工业总公司',
#  '广东第二核电站',
#  '公安部出入境管理局',
#  '美赞臣（中国）基金会',
#  '新疆八一棉纺织厂',
#  '南非广播公司',
#  '日本雪印株式会社',
#  '辽宁瓦房店市公安交通警察大队',
#  '春兰集团',
#  '瑞士苏黎世集团',
#  '中国教育学会华茂培训中心',
#  '美国空军',
#  '北京铁路分局',
#  '郑州友谊商业（集团）总公司',
#  '四川新兴集团公司',
#  '联合国儿童基金会',
#  '岳阳市委',
#  '万德莱公司',
#  '国家防汛抗旱总指挥部',
#  '人民解放军总参',
#  '北京第一社会福利院',
#  '巴勒斯坦解放组织政治部',
#  '北京航空航天大学',
#  '香港联交所上市股份公司',
#  '花城出版社',
#  '美国联邦储备委员会',
#  '天津高达医药保健品公司',
#  '武警北京一总队天安门国旗护卫队',
#  '太原军分区',
#  '北京建行',
#  '潮州市委',
#  '上海话剧艺术中心',
#  '吉林省气象服务公司',
#  '伦敦学联',
#  '新业公司',
#  '安阳机床厂',
#  '中国电子音响工业协会',
#  '中直机关工委',
#  '国家测绘局',
#  '拉合尔高等法院',
#  '湖北荆州财税学校',
#  '中国农业发展银行河南省南阳市分行办公室',
#  '上海贝尔公司',
#  '西南航空公司乘务部',
#  '中汇制药公司',
#  '齐鲁石化',
#  '湖北大江机床厂',
#  '国务院军转办',
#  '波兰议会',
#  '总后驻石家庄某物资供应站',
#  '泰国最高法院',
#  '日大藏省',
#  '美国电话电报公司',
#  '国家新药研究与开发协调领导小组',
#  '翠竹集团公司',
#  '日本自卫队',
#  '全国法律硕士专业学位教育指导委员会',
#  '舞蹈学院',
#  '中国香港业余体育协会',
#  '青岛市市南区团委',
#  '中唱总公司',
#  '永嘉县委',
#  '上海国际金融中心',
#  '西屋电气',
#  '匈牙利全国警察总署',
#  '国家体委冬运中心',
#  '南政府',
#  '辽宁盼盼集团',
#  '中国红十字会基金会',
#  '沈阳军区队',
#  '延边敖东队',
#  '坎帕拉国际会议中心',
#  '农行河南省分行',
#  '国家科委扶贫办青年志愿者扶贫接力计划静乐项目９６—９７年度服务队',
#  '合肥市人代会',
#  '萨尔瓦多市港口管理局',
#  '全国文联',
#  '顶效开发区',
#  '福建莆田县平民医院',
#  '中国西南航空公司',
#  '太原军分区门诊部',
#  '四川省就业局',
#  '芝加哥第一国民银行',
#  '桥梁厂小学队',
#  '荷兰队',
#  '纽约联合国总部',
#  '阿拉伯议会联盟委员会',
#  '新世纪出版社',
#  '中国航空油料华北公司',
#  '美国微软公司',
#  '电子工业部',
#  '中南财经大学党委',
#  '锡山市委',
#  '美国电力能源公司',
#  '东方歌舞团',
#  '韩国现代重工',
#  '萍乡市委',
#  '北京市体委',
#  '大庆市委',
#  '江苏南钢队',
#  '海南汽车工业公司北海公司',
#  '八方集团',
#  '中国法学会',
#  '合肥市委',
#  '北京医科大学',
#  '中国书刊发行业协会',
#  '中国教育学会',
#  '江南集团',
#  '浪潮电子信息产业集团公司',
#  '北京宣武区风雷京剧团',
#  '济南市二轻局',
#  '伊盟化工',
#  '外交学会',
#  '冀中钢材厂',
#  '陕西省咸阳市秦都区人民检察院',
#  '广播电影电视部',
#  '国家电力公司',
#  '欧佩克',
#  '巴西伯南布哥联邦大学药理系',
#  '西藏乃东县结莎居委会',
#  '长春佳林实业集团',
#  '中国国务院',
#  '桂光集团有限公司',
#  '中共湖南岳阳市委',
#  '富润集团',
#  '襄樊铁路医院',
#  '春兰集团公司',
#  '五芳斋粽子公司',
#  '团中央青农部',
#  '香港特别行政区红十字会',
#  '香港首届立法会',
#  '中国驻加大使馆',
#  '光明日报文艺部',
#  '河北省保定市交警三大队八中队',
#  '美国华盛顿大学',
#  '朝人民军',
#  '解放军３７４１６部队政治处',
#  '飞鹰集团公司',
#  '中国建设银行',
#  '政协河南省第八届委员会',
#  '中央顾问委员会',
#  '中共河北省委',
#  '国家信息中心',
#  '雅戈尔西服厂',
#  '印度尼西亚建设银行',
#  '奥地利维也纳音乐协会',
#  '北京市中加学校',
#  '中央委员会',
#  '广东队',
#  '美国思科公司',
#  '中央财经大学',
#  '苏伊士运河管理局',
#  '中国新兴（集团）总公司',
#  '上海远东队',
#  '古巴国务委员会',
#  '广州摩托集团',
#  '延安中央党校',
#  '国际橄榄球理事会',
#  '广州造船厂',
#  '沈阳备灾救灾中心',
#  '山西省平遥县保成实业有限责任公司',
#  '北京协和医院',
#  '海南汽车工业公司',
#  '中国奥委会新闻委员会',
#  '庄河市委',
#  '西南师范大学',
#  '中国国际广播电台',
#  '张家口铁路工厂',
#  '新疆维吾尔自治区巴音郭楞蒙古自治州文工团',
#  '马达加斯加政府',
#  '巴参议院',
#  '中国防伪行业协会',
#  '北京工业学院',
#  '中国对外友协',
#  '中纪委监察部',
#  '乌拉圭邮政局',
#  '黄粱梦派出所',
#  '保定公安局',
#  '海南省政府',
#  '邮发服务有限公司',
#  '浙江大学',
#  '长沙市望月村第二小学',
#  '北京市体育竞赛管理中心',
#  '河南大京九集团',
#  '中国全国人大',
#  '中办老干部局',
#  '国防大学',
#  '国家计委外资司',
#  '海南出版社',
#  '国家经贸委',
#  '上海市公安局南京东路警察署',
#  '中央纪律检查委员会常务委员会',
#  '文汇出版社',
#  '东方通信',
#  '呼市政府',
#  '全国银行卡信息交换中心',
#  '美国国务院',
#  '晋冀鲁豫中央局',
#  '河北省科协',
#  '西安青云中学',
#  '中国社科院台湾研究所',
#  '成都中医药大学附属医院',
#  '鲁能集团',
#  '北方航空公司',
#  '阿拉伯国家联盟',
#  '国家语言文字工作委员会',
#  '华韵影视光盘公司',
#  '劳伦斯伯克利国家实验室',
#  '安丘市晨星化学清洗服务中心',
#  '农业部农业司',
#  '河北太行集团',
#  '朝阳区朝外街道',
#  '广东省深圳市眼科医院',
#  '辽宁华森医药保健品集团有限公司',
#  '俄罗斯阿尔谢耶夫旅游公司',
#  '多伦多华人团体联合会',
#  '安徽省安庆市委党校',
#  '中国少年儿童出版社',
#  '江西电视台',
#  '荷兰文化教育福利部',
#  '大兴东方炼油厂',
#  '益阳地委',
#  '农业银行湖南省分行',
#  '长江水利委员会监理部',
#  '湖南省新华书店',
#  '南京军区南京总医院',
#  '武警河北省总队',
#  '国民西敏寺银行集团',
#  '宁夏回族自治区农林科学院农作物研究所',
#  '北京市桥牌运动协会',
#  '许昌市豫剧团',
#  '兵器工业总公司',
#  '贵州玉屏县委办公室',
#  '国务院三峡建委',
#  '莫桑比克政府',
#  '宝鸡电池厂',
#  '云南省第二人民医院',
#  '中国国务院发展研究中心',
#  '浙江农行',
#  '中国政府',
#  '日本东京地方检察厅特别搜查部',
#  '越南国家银行',
#  '重庆市委',
#  '军委总部',
#  '沁县办事处',
#  'ＴＣＬ集团有限公司',
#  '拉伯蒂特室内乐团',
#  '八路军工作团',
#  '美国国会图书馆',
#  '四川省泸州市第二中学',
#  '加拿大保险局',
#  '周村区法院',
#  '中山大学',
#  '中亚联盟',
#  '湖北宜昌县委宣传部',
#  '上海国际航运中心',
#  '广东顺德市委',
#  '嘉华银行',
#  '日本排协',
#  '中国文化办公设备制造行业协会',
#  '黄埔同学会',
#  '黑龙江省肇东市哈尔滨医科大学附属第二医院',
#  '海南航空股份有限公司',
#  '吉林市公用局',
#  '山东省日照市委',
#  '花旗银行',
#  '中国人民解放军总医院',
#  '太岳区党委',
#  '贵州省贵阳市委宣传部',
#  '太岳军政委员会',
#  '江西省农科院',
#  '广西壮族自治区党委宣传部',
#  '塘沽区政府',
#  '中国惠普医疗产品事业部',
#  '人民日报评论部',
#  '巨人集团',
#  '１６１中学',
#  '贝宁政府',
#  '江苏康博集团公司',
#  '日本太阳党',
#  '欧盟部长理事会',
#  '麦当劳中国餐厅',
#  '临洮团县委',
#  '国际海洋学院',
#  '步长公司',
#  '青海明胶',
#  '安徽社科院',
#  '福建女排',
#  '赞比亚政府',
#  '中国热带农业科学院',
#  '湖北队',
#  '马来西亚队',
#  '国务院三峡建设委员会',
#  '波音公司',
#  '上海队',
#  '俄罗斯黑手党',
#  '三峡总公司',
#  '中国进出口银行',
#  '西藏红十字会',
#  '嘉兴中远国际货运有限公司',
#  '国家统计局城调队',
#  '齐齐哈尔队',
#  '天津邮电局',
#  '中共陕甘宁边区党委',
#  '山西画院',
#  '罗马林琴科学院',
#  '中国国家橄榄球队',
#  '中国外文出版发行事业局',
#  '天津市塘沽海洋高科技开发区',
#  '浙江依多金企业集团公司',
#  '青岛市委',
#  '肥东县供电局',
#  '大同市委',
#  '中央电视台央视调查咨询中心',
#  '中国艺术研究院',
#  '浙江省德清县计划生育宣传技术指导站',
#  '上海基础公司',
#  '国家劳动部',
#  '林业部综合计划司',
#  '上海港务局',
#  '中国新疆乌鲁木齐市歌舞团',
#  '日中友好会馆',
#  '北京语言学院',
#  '陕西人民教育出版社',
#  '安徽省纪委',
#  '中日青年交流中心',
#  '毛岛爱德华·弗朗西斯公司',
#  '中央纪委监察部',
#  '新加坡巴林期货公司',
#  '东城区公证处',
#  '长沙卷烟厂',
#  '香港特区第一届立法会',
#  '印度人民党',
#  '北京辅仁大学物理系',
#  '广电部中央卫星电视传播中心',
#  '中共第八次全国代表大会',
#  '杭州冠生园食品厂',
#  '国家机电产品进出口办公室',
#  '凤凰山农药股份有限公司',
#  '当河监狱',
#  '云南省委',
#  '全国青少年爱国主义读书教育活动组织委员会',
#  '延安总政后勤部招待所',
#  '上海“绿康”配销中心',
#  '改革俱乐部',
#  '中国天津ＳＯＳ儿童村',
#  '海南省省委',
#  '武汉市政协',
#  '第三机械工业部教育局',
#  '中国大马戏团',
#  '山西省新华书店',
#  '香港新鸿基地产发展有限公司',
#  '瀛海威公司',
#  '张掖市南关小学',
#  '东征军总政治部',
#  '山西省朔州市委',
#  '深圳市政府',
#  '江苏红豆集团公司',
#  '中国社会科学院',
#  'ＢＨＡ航空复合材料有限公司',
#  '北京服装学院',
#  '云南省江川县科协',
#  '北京大学',
#  '晨星化学清洗服务中心',
#  '农行河南分行',
#  '中散（天远）公司',
#  '亚太经济合作组织',
#  '湘西土家族苗族自治州永顺县二中',
#  '加拿大冰球协会',
#  '大昭寺民管会',
#  '康泰公司',
#  '华南热带农业大学',
#  '广东省话剧院',
#  '国务院军转安置工作小组',
#  '江西省东乡县采茶剧团',
#  '四川省剑阁县新华书店农村图书发行股',
#  '清华大学',
#  '纽约市议会',
#  '路桥区委',
#  '淄博市鲁中律师事务所',
#  '日本三菱财团',
#  '中共晋冀豫省委',
#  '重庆大学',
#  '以色列政府',
#  '波兰消费者医疗中心',
#  '中国期刊协会',
#  '昆明建华集团',
#  '北京韩村河建筑集团总公司',
#  '联合国负责销毁伊拉克大规模杀伤性武器特委会',
#  '中国老年基金会',
#  '爱尔兰政府',
#  '广西壮族自治区党委',
#  '水东乡党委',
#  '国务院新闻办',
#  '肯尼亚选举委员会',
#  '重庆医科大学附属第二医院',
#  '湖北男排',
#  '工行北京分行',
#  '晋中印刷厂',
#  '北京化工四厂',
#  '蒙古政府',
#  '长城国际传播有限公司',
#  '全国资源委',
#  '中国基督教协会',
#  '水利部财务司',
#  '湖南省肿瘤医院',
#  '内塔尼亚胡政府',
#  '中直纪工委',
#  ...}

# %%
"武汉" in entities['ns']
# Out:
# True

# %% [markdown]
# ### 创建数据管道

# %%
# 加载数据

import pickle

pickle_path = '../datasets/ner/renmin/renmindata.pkl'
with open(pickle_path, 'rb') as inp:
    word2id = pickle.load(inp)
    id2word = pickle.load(inp)
    tag2id = pickle.load(inp)
    id2tag = pickle.load(inp)
    x_train = pickle.load(inp)
    y_train = pickle.load(inp)
    x_test = pickle.load(inp)
    y_test = pickle.load(inp)
    x_valid = pickle.load(inp)
    y_valid = pickle.load(inp)
print("train len:", len(x_train))
print("test len:", len(x_test))
print("valid len:", len(x_valid))
# Out:
# train len: 24271
# test len: 7585
# valid len: 6068

# %%
# # 保存词汇表和标签

# with open('../datasets/ner/renmin/vocab.pkl', 'wb') as outp:
#     pickle.dump(word2id, outp)
#     pickle.dump(id2word, outp)    

# with open('../datasets/ner/renmin/tags.pkl', 'wb') as outp:
#     pickle.dump(tag2id, outp)
#     pickle.dump(id2tag, outp)

# %%
id2tag
# Out:
# {0: 'E_nt',
#  1: 'M_nt',
#  2: 'E_nr',
#  3: 'O',
#  4: 'B_nr',
#  5: 'B_ns',
#  6: 'M_ns',
#  7: 'E_ns',
#  8: 'M_nr',
#  9: 'B_nt'}

# %%
id2word
# Out:
# {1: '的',
#  2: '国',
#  3: '一',
#  4: '在',
#  5: '中',
#  6: '人',
#  7: '１',
#  8: '了',
#  9: '和',
#  10: '是',
#  11: '有',
#  12: '年',
#  13: '大',
#  14: '不',
#  15: '０',
#  16: '为',
#  17: '会',
#  18: '业',
#  19: '上',
#  20: '地',
#  21: '发',
#  22: '出',
#  23: '９',
#  24: '作',
#  25: '要',
#  26: '工',
#  27: '行',
#  28: '民',
#  29: '这',
#  30: '经',
#  31: '家',
#  32: '新',
#  33: '个',
#  34: '日',
#  35: '部',
#  36: '以',
#  37: '来',
#  38: '到',
#  39: '２',
#  40: '市',
#  41: '成',
#  42: '生',
#  43: '对',
#  44: '进',
#  45: '全',
#  46: '我',
#  47: '们',
#  48: '政',
#  49: '多',
#  50: '主',
#  51: '时',
#  52: '他',
#  53: '产',
#  54: '本',
#  55: '展',
#  56: '长',
#  57: '实',
#  58: '者',
#  59: '学',
#  60: '方',
#  61: '建',
#  62: '（',
#  63: '）',
#  64: '开',
#  65: '理',
#  66: '同',
#  67: '动',
#  68: '月',
#  69: '高',
#  70: '关',
#  71: '重',
#  72: '力',
#  73: '电',
#  74: '现',
#  75: '于',
#  76: '公',
#  77: '５',
#  78: '社',
#  79: '下',
#  80: '３',
#  81: '报',
#  82: '区',
#  83: '加',
#  84: '分',
#  85: '济',
#  86: '制',
#  87: '自',
#  88: '化',
#  89: '定',
#  90: '文',
#  91: '体',
#  92: '过',
#  93: '前',
#  94: '合',
#  95: '等',
#  96: '场',
#  97: '就',
#  98: '天',
#  99: '与',
#  100: '说',
#  101: '面',
#  102: '：',
#  103: '后',
#  104: '记',
#  105: '机',
#  106: '事',
#  107: '法',
#  108: '员',
#  109: '用',
#  110: '４',
#  111: '能',
#  112: '美',
#  113: '得',
#  114: '７',
#  115: '资',
#  116: '８',
#  117: '华',
#  118: '也',
#  119: '外',
#  120: '十',
#  121: '务',
#  122: '之',
#  123: '而',
#  124: '设',
#  125: '总',
#  126: '好',
#  127: '６',
#  128: '北',
#  129: '平',
#  130: '利',
#  131: '金',
#  132: '农',
#  133: '各',
#  134: '子',
#  135: '元',
#  136: '小',
#  137: '将',
#  138: '从',
#  139: '企',
#  140: '明',
#  141: '万',
#  142: '问',
#  143: '提',
#  144: '当',
#  145: '心',
#  146: '两',
#  147: '其',
#  148: '；',
#  149: '表',
#  150: '种',
#  151: '委',
#  152: '党',
#  153: '品',
#  154: '可',
#  155: '里',
#  156: '度',
#  157: '强',
#  158: '改',
#  159: '着',
#  160: '军',
#  161: '代',
#  162: '起',
#  163: '内',
#  164: '目',
#  165: '京',
#  166: '通',
#  167: '科',
#  168: '入',
#  169: '三',
#  170: '系',
#  171: '活',
#  172: '水',
#  173: '第',
#  174: '位',
#  175: '都',
#  176: '导',
#  177: '次',
#  178: '题',
#  179: '特',
#  180: '道',
#  181: '所',
#  182: '世',
#  183: '向',
#  184: '去',
#  185: '省',
#  186: '领',
#  187: '增',
#  188: '还',
#  189: '已',
#  190: '—',
#  191: '基',
#  192: '海',
#  193: '使',
#  194: '管',
#  195: '最',
#  196: '今',
#  197: '名',
#  198: '术',
#  199: '统',
#  200: '立',
#  201: '南',
#  202: '结',
#  203: '并',
#  204: '技',
#  205: '些',
#  206: '正',
#  207: '应',
#  208: '持',
#  209: '交',
#  210: '安',
#  211: '点',
#  212: '西',
#  213: '性',
#  214: '东',
#  215: '任',
#  216: '共',
#  217: '联',
#  218: '由',
#  219: '解',
#  220: '界',
#  221: '《',
#  222: '》',
#  223: '组',
#  224: '教',
#  225: '治',
#  226: '保',
#  227: '院',
#  228: '司',
#  229: '队',
#  230: '决',
#  231: '意',
#  232: '程',
#  233: '及',
#  234: '门',
#  235: '期',
#  236: '情',
#  237: '调',
#  238: '取',
#  239: '达',
#  240: '村',
#  241: '义',
#  242: '间',
#  243: '张',
#  244: '量',
#  245: '团',
#  246: '此',
#  247: '局',
#  248: '如',
#  249: '干',
#  250: '战',
#  251: '据',
#  252: '广',
#  253: '．',
#  254: '议',
#  255: '书',
#  256: '收',
#  257: '革',
#  258: '府',
#  259: '因',
#  260: '把',
#  261: '际',
#  262: '路',
#  263: '江',
#  264: '步',
#  265: '计',
#  266: '山',
#  267: '然',
#  268: '二',
#  269: '集',
#  270: '比',
#  271: '育',
#  272: '相',
#  273: '放',
#  274: '志',
#  275: '价',
#  276: '办',
#  277: '先',
#  278: '举',
#  279: '信',
#  280: '亚',
#  281: '众',
#  282: '物',
#  283: '口',
#  284: '项',
#  285: '更',
#  286: '克',
#  287: '近',
#  288: '节',
#  289: '老',
#  290: '职',
#  291: '话',
#  292: '风',
#  293: '无',
#  294: '规',
#  295: '看',
#  296: '指',
#  297: '五',
#  298: '族',
#  299: '认',
#  300: '但',
#  301: '形',
#  302: '拉',
#  303: '求',
#  304: '困',
#  305: '商',
#  306: '手',
#  307: '论',
#  308: '％',
#  309: '斯',
#  310: '难',
#  311: '精',
#  312: '车',
#  313: '深',
#  314: '格',
#  315: '质',
#  316: '少',
#  317: '运',
#  318: '研',
#  319: '原',
#  320: '处',
#  321: '李',
#  322: '想',
#  323: '台',
#  324: '条',
#  325: '受',
#  326: '施',
#  327: '式',
#  328: '件',
#  329: '图',
#  330: '气',
#  331: '观',
#  332: '级',
#  333: '群',
#  334: '春',
#  335: '数',
#  336: '又',
#  337: '女',
#  338: '县',
#  339: '央',
#  340: '传',
#  341: '别',
#  342: '造',
#  343: '创',
#  344: '剧',
#  345: '四',
#  346: '果',
#  347: '给',
#  348: '首',
#  349: '没',
#  350: '协',
#  351: '投',
#  352: '支',
#  353: '城',
#  354: '推',
#  355: '至',
#  356: '乡',
#  357: '常',
#  358: '样',
#  359: '片',
#  360: '回',
#  361: '神',
#  362: '变',
#  363: '思',
#  364: '选',
#  365: '只',
#  366: '服',
#  367: '示',
#  368: '几',
#  369: '标',
#  370: '争',
#  371: '周',
#  372: '整',
#  373: '证',
#  374: '视',
#  375: '贫',
#  376: '优',
#  377: '接',
#  378: '极',
#  379: '纪',
#  380: '查',
#  381: '王',
#  382: '流',
#  383: '那',
#  384: '专',
#  385: '反',
#  386: '续',
#  387: '尔',
#  388: '被',
#  389: '见',
#  390: '百',
#  391: '做',
#  392: '单',
#  393: '头',
#  394: '营',
#  395: '效',
#  396: '势',
#  397: '德',
#  398: '融',
#  399: '参',
#  400: '构',
#  401: '马',
#  402: '很',
#  403: '究',
#  404: '历',
#  405: '织',
#  406: '积',
#  407: '副',
#  408: '林',
#  409: '住',
#  410: '费',
#  411: '亿',
#  412: '布',
#  413: '灾',
#  414: '走',
#  415: '坚',
#  416: '影',
#  417: '艺',
#  418: '感',
#  419: '户',
#  420: '房',
#  421: '史',
#  422: '演',
#  423: '真',
#  424: '身',
#  425: '席',
#  426: '益',
#  427: '再',
#  428: '·',
#  429: '线',
#  430: '每',
#  431: '该',
#  432: '率',
#  433: '光',
#  434: '助',
#  435: '谈',
#  436: '己',
#  437: '必',
#  438: '严',
#  439: '望',
#  440: '乐',
#  441: '根',
#  442: '策',
#  443: '才',
#  444: '列',
#  445: '快',
#  446: '赛',
#  447: '供',
#  448: '清',
#  449: '非',
#  450: '批',
#  451: '完',
#  452: '许',
#  453: '转',
#  454: '色',
#  455: '或',
#  456: '罗',
#  457: '带',
#  458: '责',
#  459: '确',
#  460: '州',
#  461: '河',
#  462: '知',
#  463: '权',
#  464: '型',
#  465: '打',
#  466: '具',
#  467: '伊',
#  468: '港',
#  469: '准',
#  470: '银',
#  471: '它',
#  472: '引',
#  473: '识',
#  474: '八',
#  475: '何',
#  476: '需',
#  477: '英',
#  478: '股',
#  479: '兴',
#  480: '象',
#  481: '连',
#  482: '直',
#  483: '防',
#  484: '况',
#  485: '九',
#  486: '医',
#  487: '值',
#  488: '采',
#  489: '约',
#  490: '花',
#  491: '讯',
#  492: '始',
#  493: '送',
#  494: '命',
#  495: '案',
#  496: '巴',
#  497: '环',
#  498: '么',
#  499: '游',
#  500: '切',
#  501: '易',
#  502: '刘',
#  503: '范',
#  504: '米',
#  505: '武',
#  506: '消',
#  507: '客',
#  508: '划',
#  509: '致',
#  510: '响',
#  511: '青',
#  512: '功',
#  513: '球',
#  514: '继',
#  515: '则',
#  516: '阿',
#  517: '款',
#  518: '速',
#  519: '落',
#  520: '段',
#  521: '仅',
#  522: '越',
#  523: '爱',
#  524: '稳',
#  525: '空',
#  526: '境',
#  527: '模',
#  528: '告',
#  529: '士',
#  530: '较',
#  531: '备',
#  532: '源',
#  533: '石',
#  534: '往',
#  535: '获',
#  536: '富',
#  537: '双',
#  538: '厂',
#  539: '负',
#  540: '热',
#  541: '警',
#  542: '儿',
#  543: '钱',
#  544: '包',
#  545: '洲',
#  546: '她',
#  547: '讲',
#  548: '访',
#  549: '亲',
#  550: '断',
#  551: '你',
#  552: '满',
#  553: '评',
#  554: '香',
#  555: '陈',
#  556: '素',
#  557: '护',
#  558: '维',
#  559: '健',
#  560: '『',
#  561: '』',
#  562: '…',
#  563: '声',
#  564: '初',
#  565: '照',
#  566: '宣',
#  567: '息',
#  568: '希',
#  569: '泽',
#  570: '依',
#  571: '晚',
#  572: '千',
#  573: '欧',
#  574: '远',
#  575: '排',
#  576: '类',
#  577: '镇',
#  578: '未',
#  579: '字',
#  580: '震',
#  581: '俄',
#  582: '油',
#  583: '友',
#  584: '低',
#  585: '版',
#  586: '红',
#  587: '财',
#  588: '份',
#  589: '便',
#  590: '良',
#  591: '贸',
#  592: '考',
#  593: '校',
#  594: '均',
#  595: '货',
#  596: '尼',
#  597: '层',
#  598: '失',
#  599: '师',
#  600: '销',
#  601: '检',
#  602: '土',
#  603: '让',
#  604: '须',
#  605: '存',
#  606: '监',
#  607: '善',
#  608: '抓',
#  609: '律',
#  610: '显',
#  611: '居',
#  612: '核',
#  613: '突',
#  614: '届',
#  615: '救',
#  616: '波',
#  617: '边',
#  618: '复',
#  619: '足',
#  620: '占',
#  621: '装',
#  622: '荣',
#  623: '验',
#  624: '础',
#  625: '按',
#  626: '促',
#  627: '扶',
#  628: '斗',
#  629: '夫',
#  630: '摄',
#  631: '容',
#  632: '习',
#  633: '紧',
#  634: '余',
#  635: '欢',
#  636: '黄',
#  637: '养',
#  638: '普',
#  639: '培',
#  640: '献',
#  641: '岗',
#  642: '古',
#  643: '站',
#  644: '迎',
#  645: '官',
#  646: '减',
#  647: '铁',
#  648: '注',
#  649: '域',
#  650: '白',
#  651: '围',
#  652: '即',
#  653: '器',
#  654: '随',
#  655: '兵',
#  656: '汇',
#  657: '雪',
#  658: '旅',
#  659: '飞',
#  660: '太',
#  661: '限',
#  662: '票',
#  663: '努',
#  664: '闻',
#  665: '充',
#  666: '奖',
#  667: '执',
#  668: '尽',
#  669: '劳',
#  670: '福',
#  671: '破',
#  672: '景',
#  673: '预',
#  674: '温',
#  675: '食',
#  676: '云',
#  677: '六',
#  678: '愿',
#  679: '承',
#  680: '察',
#  681: '岁',
#  682: '税',
#  683: '阳',
#  684: '措',
#  685: '略',
#  686: '临',
#  687: '态',
#  688: '却',
#  689: '除',
#  690: '降',
#  691: '菜',
#  692: '危',
#  693: '庆',
#  694: '挥',
#  695: '配',
#  696: '宁',
#  697: '喜',
#  698: '售',
#  699: '念',
#  700: '岸',
#  701: '且',
#  702: '田',
#  703: '龙',
#  704: '帮',
#  705: '读',
#  706: '班',
#  707: '网',
#  708: '写',
#  709: '曾',
#  710: '险',
#  711: '离',
#  712: '币',
#  713: '终',
#  714: '音',
#  715: '伟',
#  716: '早',
#  717: '言',
#  718: '丰',
#  719: '属',
#  720: '称',
#  721: '歌',
#  722: '舞',
#  723: '虎',
#  724: '卫',
#  725: '驻',
#  726: '火',
#  727: '担',
#  728: '康',
#  729: '额',
#  730: '请',
#  731: '苦',
#  732: '升',
#  733: '号',
#  734: '底',
#  735: '待',
#  736: '独',
#  737: '控',
#  738: '购',
#  739: '药',
#  740: '料',
#  741: '苏',
#  742: '像',
#  743: '七',
#  744: '邓',
#  745: '顿',
#  746: '竞',
#  747: '病',
#  748: '藏',
#  749: '兰',
#  750: '令',
#  751: '半',
#  752: '眼',
#  753: '祖',
#  754: '派',
#  755: '湾',
#  756: '航',
#  757: '章',
#  758: '哈',
#  759: '算',
#  760: '什',
#  761: '置',
#  762: '超',
#  763: '针',
#  764: '胜',
#  765: '买',
#  766: '吃',
#  767: '训',
#  768: '塔',
#  769: '印',
#  770: '介',
#  771: '互',
#  772: '树',
#  773: '扩',
#  774: '阶',
#  775: '星',
#  776: '汉',
#  777: '适',
#  778: '击',
#  779: '画',
#  780: '留',
#  781: '附',
#  782: '密',
#  783: '刚',
#  784: '仍',
#  785: '修',
#  786: '探',
#  787: '候',
#  788: '纳',
#  789: '试',
#  790: '故',
#  791: '牌',
#  792: '彩',
#  793: '轻',
#  794: '状',
#  795: '烈',
#  796: '庭',
#  797: '巨',
#  798: '听',
#  799: '审',
#  800: '冬',
#  801: '编',
#  802: '恩',
#  803: '座',
#  804: '奋',
#  805: '止',
#  806: '馆',
#  807: '犯',
#  808: '湖',
#  809: '园',
#  810: '孩',
#  811: '换',
#  812: '害',
#  813: '奥',
#  814: '著',
#  815: '逐',
#  816: '抗',
#  817: '祝',
#  818: '索',
#  819: '午',
#  820: '盟',
#  821: '幅',
#  822: '刻',
#  823: '典',
#  824: '礼',
#  825: '急',
#  826: '召',
#  827: '戏',
#  828: '罪',
#  829: '久',
#  830: '绍',
#  831: '秀',
#  832: '脱',
#  833: '吉',
#  834: '激',
#  835: '例',
#  836: '卡',
#  837: '胡',
#  838: '测',
#  839: '桥',
#  840: '室',
#  841: '损',
#  842: '贵',
#  843: '拥',
#  844: '吴',
#  845: '材',
#  846: '彻',
#  847: '兼',
#  848: '脑',
#  849: '韩',
#  850: '卖',
#  851: '判',
#  852: '盛',
#  853: '播',
#  854: '纷',
#  855: '贯',
#  856: '贷',
#  857: '署',
#  858: '私',
#  859: '既',
#  860: '绩',
#  861: '谢',
#  862: '泰',
#  863: '曲',
#  864: '败',
#  865: '呼',
#  866: '靠',
#  867: '拿',
#  868: '永',
#  869: '搞',
#  870: '尚',
#  871: '括',
#  872: '短',
#  873: '血',
#  874: '顺',
#  875: '移',
#  876: '绝',
#  877: '堂',
#  878: '夜',
#  879: '洋',
#  880: '矿',
#  881: '鲜',
#  882: '觉',
#  883: '违',
#  884: '差',
#  885: '船',
#  886: '草',
#  887: '灯',
#  888: '映',
#  889: '暖',
#  890: '予',
#  891: '店',
#  892: '停',
#  893: '杨',
#  894: '津',
#  895: '黑',
#  896: '捐',
#  897: '威',
#  898: '艰',
#  899: '钟',
#  900: '繁',
#  901: '录',
#  902: '顾',
#  903: '语',
#  904: '够',
#  905: '压',
#  906: '玉',
#  907: '街',
#  908: '冷',
#  909: '督',
#  910: '某',
#  911: '券',
#  912: '招',
#  913: '讨',
#  914: '束',
#  915: '宏',
#  916: '妇',
#  917: '疗',
#  918: '木',
#  919: '库',
#  920: '楼',
#  921: '粮',
#  922: '赞',
#  923: '瑞',
#  924: '雨',
#  925: '孙',
#  926: '托',
#  927: '扬',
#  928: '缺',
#  929: '赵',
#  930: '吸',
#  931: '另',
#  932: '套',
#  933: '鼓',
#  934: '诉',
#  935: '归',
#  936: '旦',
#  937: '毛',
#  938: '贺',
#  939: '童',
#  940: '找',
#  941: '邮',
#  942: '践',
#  943: '笔',
#  944: '鹏',
#  945: '坦',
#  946: '遇',
#  947: '述',
#  948: '盘',
#  949: '征',
#  950: '腐',
#  951: '慰',
#  952: '旗',
#  953: '假',
#  954: '输',
#  955: '男',
#  956: '否',
#  957: '川',
#  958: '贡',
#  959: '虽',
#  960: '厅',
#  961: '伍',
#  962: '债',
#  963: '叶',
#  964: '母',
#  965: '退',
#  966: '徐',
#  967: '左',
#  968: '冰',
#  969: '冲',
#  970: '序',
#  971: '雷',
#  972: '钢',
#  973: '杂',
#  974: '补',
#  975: '亮',
#  976: '沙',
#  977: '综',
#  978: '甚',
#  979: '廉',
#  980: '烟',
#  981: '练',
#  982: '课',
#  983: '角',
#  984: '汽',
#  985: '守',
#  986: '析',
#  987: '丽',
#  988: '篮',
#  989: '伤',
#  990: '振',
#  991: '夏',
#  992: '固',
#  993: '轮',
#  994: '免',
#  995: '励',
#  996: '鲁',
#  997: '宝',
#  998: '朝',
#  999: '朱',
#  1000: '登',
#  ...}

# %%
tag2id
# Out:
# {'E_nt': 0,
#  'M_nt': 1,
#  'E_nr': 2,
#  'O': 3,
#  'B_nr': 4,
#  'B_ns': 5,
#  'M_ns': 6,
#  'E_ns': 7,
#  'M_nr': 8,
#  'B_nt': 9}

# %%
word2id['[PAD]']
# Out:
# 0

# %%
strs = "深圳欢迎您"
for char in strs:
    print(word2id[char])
# Out:
# 313
# 1456
# 635
# 644
# 1458

# %%
# 创建数据管道

import torch
from torch.utils.data import Dataset,DataLoader
import torch.nn as nn
import torch.optim as optim


batch_size = 32  # batch size
num_workers = 4  # how many workers for loading data



class NERDataset(Dataset):
    def __init__(self, X, Y, *args, **kwargs):
        self.data = [{'x': X[i], 'y': Y[i]} for i in range(X.shape[0])]

    def __getitem__(self, index):
        return self.data[index]

    def __len__(self):
        return len(self.data)


train_dataset = NERDataset(x_train, y_train)
valid_dataset = NERDataset(x_valid, y_valid)
test_dataset = NERDataset(x_test, y_test)

train_dataloader = DataLoader(train_dataset,
                              batch_size=batch_size,
                              shuffle=True,
                              num_workers=num_workers)
valid_dataloader = DataLoader(valid_dataset,
                              batch_size=batch_size,
                              shuffle=True,
                              num_workers=num_workers)
test_dataloader = DataLoader(test_dataset,
                             batch_size=batch_size,
                             shuffle=True,
                             num_workers=num_workers)

# %% [markdown]
# ## 训练模型

# %% [markdown]
# ### BiLSTM

# %%
device
# Out:
# device(type='cuda')

# %%
class Config:
    embedding_dim = 100
    hidden_dim = 200

    vocab_size = len(word2id)
    num_tags = len(tag2id)

    dropout = 0.2
    lr = 0.001
    weight_decay = 1e-5

# 创建模型，优化器，评价标准
config = Config()
model = NERLSTM_CRF(config).to(device)
criterion = nn.CrossEntropyLoss(ignore_index=0)
optimizer = optim.Adam(model.parameters(),
                       lr=config.lr,
                       weight_decay=config.weight_decay)

# %%
# 用于将实体类别解码，单字组合成单词

def parse_tags(text, path):
    tags = [id2tag[idx] for idx in path]

    begin = 0
    end = 0

    res = []
    for idx, tag in enumerate(tags):
        # 将连续的 同类型 的字连接起来
        if tag.startswith("B"):
            begin = idx
        elif tag.startswith("E"):
            end = idx
            word = text[begin:end + 1]
            label = tag[2:]
            res.append((word, label))
        elif tag=='O':
            res.append((text[idx], tag))
    return res

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

max_epoch = 10


class ChineseNER(object):
    def train(self):
        for epoch in range(max_epoch):

            # 训练模式
            model.train()

            for index, batch in enumerate(train_dataloader):
                # 梯度归零
                optimizer.zero_grad()

                # 训练数据-->gpu
                x = batch['x'].to(device)
                mask = (x > 0).to(device)
                y = batch['y'].to(device)
                

                # 前向计算计算损失
                loss = model.log_likelihood(x, y, mask)

                # 反向传播
                loss.backward()

                # 梯度裁剪
                torch.nn.utils.clip_grad_norm_(parameters=model.parameters(),
                                               max_norm=10)

                # 更新参数
                optimizer.step()
                if index % 200 == 0:
                    print('epoch:%5d,------------loss:%f' %
                          (epoch, loss.item()))

            # 验证损失和精度
            aver_loss = 0
            preds, labels = [], []
            for index, batch in enumerate(valid_dataloader):

                # 验证模式
                model.eval()

                # 验证数据-->gpu
                val_x, val_y = batch['x'].to(device), batch['y'].to(device)
                val_mask = (val_x > 0).to(device)
                predict = model(val_x, val_mask)

                # 前向计算损失
                loss = model.log_likelihood(val_x, val_y, val_mask)
                aver_loss += loss.item()

                # 统计非0的，也就是真实标签的长度
                leng = []
                for i in val_y.cpu():
                    tmp = []
                    for j in i:
                        if j.item() > 0:
                            tmp.append(j.item())
                    leng.append(tmp)

                for index, i in enumerate(predict):
                    preds += i[:len(leng[index])]

                for index, i in enumerate(val_y.tolist()):
                    labels += i[:len(leng[index])]

            # 损失值与评测指标
            aver_loss /= (len(valid_dataloader) * 64)
            precision = precision_score(labels, preds, average='macro')
            recall = recall_score(labels, preds, average='macro')
            f1 = f1_score(labels, preds, average='macro')
            report = classification_report(labels, preds)
            print(report)
            torch.save(model.state_dict(), '../models/ner/params.pkl')

    # 预测，输入为单句，输出为对应的单词和标签
    def predict(self, input_str=""):
        model.load_state_dict(torch.load("../models/ner/params.pkl"))
        model.eval()
        if not input_str:
            input_str = input("请输入文本: ")
        
        input_vec = []
        for char in input_str:
            if char not in word2id:
                input_vec.append(word2id['[unknown]'])
            else:
                input_vec.append(word2id[char])
                
        # convert to tensor
        sentences = torch.tensor(input_vec).view(1, -1).to(device)
        mask = sentences > 0
        paths = model(sentences, mask)

        res = parse_tags(input_str, paths[0])
        return res
    
    # 在测试集上评判性能
    def test(self, test_dataloader):
        model.load_state_dict(torch.load("../models/ner/params.pkl"))
        
        aver_loss = 0
        preds, labels = [], []
        for index, batch in enumerate(test_dataloader):

            # 验证模式
            model.eval()

            # 验证数据-->gpu
            val_x, val_y = batch['x'].to(device), batch['y'].to(device)
            val_mask = (val_x > 0).to(device)
            predict = model(val_x, val_mask)

            # 前向计算损失
            loss = model.log_likelihood(val_x, val_y, val_mask)
            aver_loss += loss.item()

            # 统计非0的，也就是真实标签的长度
            leng = []
            for i in val_y.cpu():
                tmp = []
                for j in i:
                    if j.item() > 0:
                        tmp.append(j.item())
                leng.append(tmp)

            for index, i in enumerate(predict):
                preds += i[:len(leng[index])]

            for index, i in enumerate(val_y.tolist()):
                labels += i[:len(leng[index])]

        # 损失值与评测指标
        aver_loss /= (len(test_dataloader) * 64)
        precision = precision_score(labels, preds, average='macro')
        recall = recall_score(labels, preds, average='macro')
        f1 = f1_score(labels, preds, average='macro')
        report = classification_report(labels, preds)
        print(report)

# %%
cn = ChineseNER()
# cn.train()
# Out:
# epoch:    0,------------loss:979.705811
# epoch:    0,------------loss:263.596802
# epoch:    0,------------loss:171.161011
# epoch:    0,------------loss:164.264771
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.81      1542
#            1       0.79      0.86      0.82      6459
#            2       0.88      0.79      0.83      3017
#            3       0.95      0.96      0.96     61629
#            4       0.93      0.84      0.88      3117
#            5       0.84      0.82      0.83      3586
#            6       0.73      0.67      0.70      2163
#            7       0.81      0.79      0.80      3567
#            8       0.89      0.83      0.86      2805
#            9       0.82      0.80      0.81      1763
#
#     accuracy                           0.92     89648
#    macro avg       0.84      0.82      0.83     89648
# weighted avg       0.92      0.92      0.91     89648
#
# epoch:    1,------------loss:113.367020
# epoch:    1,------------loss:97.349915
# epoch:    1,------------loss:64.200745
# epoch:    1,------------loss:43.082191
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.86      1542
#            1       0.86      0.88      0.87      6459
#            2       0.92      0.89      0.91      3017
#            3       0.97      0.97      0.97     61629
#            4       0.94      0.92      0.93      3117
#            5       0.90      0.87      0.89      3586
#            6       0.82      0.77      0.80      2163
#            7       0.88      0.85      0.87      3567
#            8       0.92      0.93      0.92      2805
#            9       0.87      0.88      0.87      1763
#
#     accuracy                           0.94     89648
#    macro avg       0.89      0.88      0.89     89648
# weighted avg       0.94      0.94      0.94     89648
#
# epoch:    2,------------loss:57.869308
# epoch:    2,------------loss:24.850203
# epoch:    2,------------loss:40.078583
# epoch:    2,------------loss:32.883598
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87      1542
#            1       0.91      0.85      0.88      6459
#            2       0.95      0.91      0.93      3017
#            3       0.96      0.99      0.97     61629
#            4       0.96      0.92      0.94      3117
#            5       0.93      0.87      0.90      3586
#            6       0.88      0.75      0.81      2163
#            7       0.90      0.85      0.88      3567
#            8       0.95      0.93      0.94      2805
#            9       0.91      0.86      0.88      1763
#
#     accuracy                           0.95     89648
#    macro avg       0.92      0.88      0.90     89648
# weighted avg       0.95      0.95      0.95     89648
#
# epoch:    3,------------loss:36.122551
# epoch:    3,------------loss:15.675191
# epoch:    3,------------loss:29.016796
# epoch:    3,------------loss:14.426651
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88      1542
#            1       0.83      0.95      0.89      6459
#            2       0.93      0.93      0.93      3017
#            3       0.98      0.97      0.98     61629
#            4       0.94      0.94      0.94      3117
#            5       0.93      0.88      0.91      3586
#            6       0.84      0.84      0.84      2163
#            7       0.92      0.87      0.89      3567
#            8       0.94      0.95      0.95      2805
#            9       0.86      0.93      0.89      1763
#
#     accuracy                           0.95     89648
#    macro avg       0.90      0.92      0.91     89648
# weighted avg       0.96      0.95      0.95     89648
#
# epoch:    4,------------loss:13.887087
# epoch:    4,------------loss:19.692810
# epoch:    4,------------loss:6.304973
# epoch:    4,------------loss:21.609739
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      1542
#            1       0.88      0.92      0.90      6459
#            2       0.96      0.91      0.93      3017
#            3       0.98      0.98      0.98     61629
#            4       0.97      0.92      0.95      3117
#            5       0.91      0.92      0.91      3586
#            6       0.82      0.87      0.84      2163
#            7       0.89      0.90      0.90      3567
#            8       0.96      0.93      0.94      2805
#            9       0.89      0.92      0.91      1763
#
#     accuracy                           0.96     89648
#    macro avg       0.91      0.92      0.92     89648
# weighted avg       0.96      0.96      0.96     89648
#
# epoch:    5,------------loss:14.560954
# epoch:    5,------------loss:19.548908
# epoch:    5,------------loss:11.793258
# epoch:    5,------------loss:21.827126
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90      1542
#            1       0.90      0.91      0.90      6459
#            2       0.94      0.93      0.94      3017
#            3       0.98      0.98      0.98     61629
#            4       0.95      0.94      0.95      3117
#            5       0.93      0.92      0.92      3586
#            6       0.87      0.84      0.86      2163
#            7       0.91      0.91      0.91      3567
#            8       0.95      0.95      0.95      2805
#            9       0.90      0.92      0.91      1763
#
#     accuracy                           0.96     89648
#    macro avg       0.92      0.92      0.92     89648
# weighted avg       0.96      0.96      0.96     89648
#
# epoch:    6,------------loss:6.402034
# epoch:    6,------------loss:6.741951
# epoch:    6,------------loss:5.291454
# epoch:    6,------------loss:6.786420
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.89      1542
#            1       0.89      0.91      0.90      6459
#            2       0.96      0.92      0.94      3017
#            3       0.98      0.98      0.98     61629
#            4       0.97      0.93      0.95      3117
#            5       0.92      0.93      0.92      3586
#            6       0.84      0.87      0.85      2163
#            7       0.91      0.91      0.91      3567
#            8       0.96      0.94      0.95      2805
#            9       0.91      0.91      0.91      1763
#
#     accuracy                           0.96     89648
#    macro avg       0.92      0.92      0.92     89648
# weighted avg       0.96      0.96      0.96     89648
#
# epoch:    7,------------loss:2.549169
# epoch:    7,------------loss:6.191164
# epoch:    7,------------loss:4.162159
# epoch:    7,------------loss:9.172005
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.89      1542
#            1       0.91      0.89      0.90      6459
#            2       0.96      0.92      0.94      3017
#            3       0.98      0.98      0.98     61629
#            4       0.97      0.93      0.95      3117
#            5       0.92      0.93      0.93      3586
#            6       0.85      0.86      0.85      2163
#            7       0.91      0.91      0.91      3567
#            8       0.97      0.93      0.95      2805
#            9       0.91      0.91      0.91      1763
#
#     accuracy                           0.96     89648
#    macro avg       0.93      0.92      0.92     89648
# weighted avg       0.96      0.96      0.96     89648
#
# epoch:    8,------------loss:2.915556
# epoch:    8,------------loss:13.219044
# epoch:    8,------------loss:0.869555
# epoch:    8,------------loss:2.149637
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90      1542
#            1       0.90      0.91      0.91      6459
#            2       0.94      0.94      0.94      3017
#            3       0.98      0.98      0.98     61629
#            4       0.95      0.95      0.95      3117
#            5       0.93      0.92      0.92      3586
#            6       0.88      0.84      0.86      2163
#            7       0.92      0.90      0.91      3567
#            8       0.94      0.96      0.95      2805
#            9       0.90      0.92      0.91      1763
#
#     accuracy                           0.96     89648
#    macro avg       0.92      0.92      0.92     89648
# weighted avg       0.96      0.96      0.96     89648
# epoch:    9,------------loss:1.087444
# epoch:    9,------------loss:1.591179
# epoch:    9,------------loss:6.660941
# epoch:    9,------------loss:1.844975
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90      1542
#            1       0.89      0.91      0.90      6459
#            2       0.96      0.93      0.95      3017
#            3       0.98      0.98      0.98     61629
#            4       0.97      0.94      0.95      3117
#            5       0.92      0.93      0.93      3586
#            6       0.85      0.88      0.86      2163
#            7       0.91      0.91      0.91      3567
#            8       0.97      0.93      0.95      2805
#            9       0.90      0.92      0.91      1763
#
#     accuracy                           0.96     89648
#    macro avg       0.92      0.92      0.92     89648
# weighted avg       0.96      0.96      0.96     89648

# %%
# 模型性能
cn.test(test_dataloader)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      1887
#            1       0.91      0.91      0.91      8043
#            2       0.95      0.91      0.93      3833
#            3       0.98      0.98      0.98     75869
#            4       0.97      0.93      0.95      3962
#            5       0.93      0.93      0.93      4520
#            6       0.85      0.86      0.85      2688
#            7       0.92      0.91      0.91      4495
#            8       0.96      0.93      0.95      3645
#            9       0.91      0.92      0.92      2146
#
#     accuracy                           0.96    111088
#    macro avg       0.93      0.92      0.92    111088
# weighted avg       0.96      0.96      0.96    111088

# %%
# 模型进行预测
cn = ChineseNER()
text = "冯永祥突发奇想，跑到阿尔及利亚旅行，意外结识了印度人民党的领导"
cn.predict(text)
# Out:
# [('冯永祥', 'nr'),
#  ('突', 'O'),
#  ('发', 'O'),
#  ('奇', 'O'),
#  ('想', 'O'),
#  ('，', 'O'),
#  ('跑', 'O'),
#  ('到', 'O'),
#  ('阿尔及利亚', 'ns'),
#  ('旅', 'O'),
#  ('行', 'O'),
#  ('，', 'O'),
#  ('意', 'O'),
#  ('外', 'O'),
#  ('结', 'O'),
#  ('识', 'O'),
#  ('了', 'O'),
#  ('印度人民党', 'nt'),
#  ('的', 'O'),
#  ('领', 'O'),
#  ('导', 'O')]

# %% [markdown]
# ## 转移矩阵

# %%
id2tag
# Out:
# {0: 'E_nt',
#  1: 'M_nt',
#  2: 'E_nr',
#  3: 'O',
#  4: 'B_nr',
#  5: 'B_ns',
#  6: 'M_ns',
#  7: 'E_ns',
#  8: 'M_nr',
#  9: 'B_nt'}

# %%
trans_matrix = torch.Tensor.cpu(model.crf.trans_matrix).detach().numpy()

# %%
df = pd.DataFrame(trans_matrix, columns=id2tag.values(), index=id2tag.values())
df
# Out:
#           E_nt      M_nt      E_nr         O      B_nr      B_ns      M_ns  \
# E_nt -2.573899 -3.030039 -0.728452  0.909396  0.266779  0.373823 -1.361368
# M_nt  2.064595  1.689258 -1.940975 -3.371228 -1.675405 -1.948209 -2.652172
# E_nr -1.452444 -1.468744 -3.259135  1.279310  0.709749 -0.101151 -1.440134
# O    -3.398406 -3.010524 -2.628851  1.655515  0.666735  0.623919 -3.150675
# B_nr -1.319444 -2.039114  1.578004 -2.857347 -3.091537 -2.269576 -3.158556
# B_ns -1.902348 -3.107933 -3.106146 -2.916749 -2.224071 -3.267369  1.963997
# M_ns -2.643914 -3.191900 -3.060015 -3.492515 -1.683115 -3.250608  1.325443
# E_ns -1.974666 -3.305349 -2.005721  1.301592  0.344891  1.072410 -3.457960
# M_nr -1.491318 -1.743178  1.773020 -2.795350 -2.651609 -1.647576 -2.428080
# B_nt -0.838918  2.111549 -1.851870 -2.921312 -1.194270 -1.949645 -3.129531
#
#           E_ns      M_nr      B_nt
# E_nt -1.049253 -0.733836  0.107502
# M_nt -2.889705 -1.326632 -3.380410
# E_nr -1.680012 -2.549911  0.288885
# O    -3.037330 -2.530541  0.677525
# B_nr -3.435970  1.800888 -1.399733
# B_ns  1.683751 -3.329149 -1.943171
# M_ns  1.899873 -2.290820 -1.446936
# E_ns -3.144714 -1.864227 -0.017089
# M_nr -3.107333  1.031566 -1.024025
# B_nt -3.415173 -2.139561 -3.436430

# %%
index = [
    'B_nt', 'M_nt', 'E_nt', 'B_nr', 'M_nr', 'E_nr', 'B_ns', 'M_ns', 'E_ns', 'O'
]
df.reindex(index, axis=0).reindex(index, axis=1).round(2).style.applymap(
    lambda v: 'background-color: %s' % '#B0C4DE'
    if v > 0 else 'background-color: %s' % '#FFFFFF')
# Out:
# <style  type="text/css" >
#     #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row0_col0 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row0_col1 {
#             background-color:  #B0C4DE;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row0_col2 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row0_col3 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row0_col4 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row0_col5 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row0_col6 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row0_col7 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row0_col8 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row0_col9 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row1_col0 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row1_col1 {
#             background-color:  #B0C4DE;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row1_col2 {
#             background-color:  #B0C4DE;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row1_col3 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row1_col4 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row1_col5 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row1_col6 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row1_col7 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row1_col8 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row1_col9 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row2_col0 {
#             background-color:  #B0C4DE;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row2_col1 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row2_col2 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row2_col3 {
#             background-color:  #B0C4DE;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row2_col4 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row2_col5 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row2_col6 {
#             background-color:  #B0C4DE;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row2_col7 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row2_col8 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row2_col9 {
#             background-color:  #B0C4DE;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row3_col0 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row3_col1 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row3_col2 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row3_col3 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row3_col4 {
#             background-color:  #B0C4DE;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row3_col5 {
#             background-color:  #B0C4DE;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row3_col6 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row3_col7 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row3_col8 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row3_col9 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row4_col0 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row4_col1 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row4_col2 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row4_col3 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row4_col4 {
#             background-color:  #B0C4DE;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row4_col5 {
#             background-color:  #B0C4DE;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row4_col6 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row4_col7 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row4_col8 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row4_col9 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row5_col0 {
#             background-color:  #B0C4DE;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row5_col1 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row5_col2 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row5_col3 {
#             background-color:  #B0C4DE;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row5_col4 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row5_col5 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row5_col6 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row5_col7 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row5_col8 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row5_col9 {
#             background-color:  #B0C4DE;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row6_col0 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row6_col1 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row6_col2 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row6_col3 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row6_col4 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row6_col5 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row6_col6 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row6_col7 {
#             background-color:  #B0C4DE;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row6_col8 {
#             background-color:  #B0C4DE;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row6_col9 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row7_col0 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row7_col1 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row7_col2 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row7_col3 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row7_col4 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row7_col5 {
#             background-color:  #FFFFFF;
#         }    #T_7b5b41f2_9f64_11ea_984f_0b9c68c508d6row7_col6 {
#             bac

# %%
start_matrix = torch.Tensor.cpu(model.crf.start_matrix.view(
    1, -1)).detach().numpy()
df = pd.DataFrame(start_matrix, columns=id2tag.values())
df.reindex(index, axis=1).round(3).style.applymap(
    lambda v: 'background-color: %s' % '#B0C4DE'
    if v > 0 else 'background-color: %s' % '#FFFFFF')
# Out:
# <style  type="text/css" >
#     #T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col0 {
#             background-color:  #FFFFFF;
#         }    #T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col1 {
#             background-color:  #FFFFFF;
#         }    #T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col2 {
#             background-color:  #B0C4DE;
#         }    #T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col3 {
#             background-color:  #FFFFFF;
#         }    #T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col4 {
#             background-color:  #FFFFFF;
#         }    #T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col5 {
#             background-color:  #FFFFFF;
#         }    #T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col6 {
#             background-color:  #FFFFFF;
#         }    #T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col7 {
#             background-color:  #B0C4DE;
#         }    #T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col8 {
#             background-color:  #FFFFFF;
#         }    #T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col9 {
#             background-color:  #B0C4DE;
#         }</style><table id="T_6f211654_9f65_11ea_984f_0b9c68c508d6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >B_nt</th>        <th class="col_heading level0 col1" >M_nt</th>        <th class="col_heading level0 col2" >E_nt</th>        <th class="col_heading level0 col3" >B_nr</th>        <th class="col_heading level0 col4" >M_nr</th>        <th class="col_heading level0 col5" >E_nr</th>        <th class="col_heading level0 col6" >B_ns</th>        <th class="col_heading level0 col7" >M_ns</th>        <th class="col_heading level0 col8" >E_ns</th>        <th class="col_heading level0 col9" >O</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6f211654_9f65_11ea_984f_0b9c68c508d6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col0" class="data row0 col0" >-0.088000</td>
#                         <td id="T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col1" class="data row0 col1" >-0.033000</td>
#                         <td id="T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col2" class="data row0 col2" >0.027000</td>
#                         <td id="T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col3" class="data row0 col3" >-0.045000</td>
#                         <td id="T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col4" class="data row0 col4" >-0.087000</td>
#                         <td id="T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col5" class="data row0 col5" >-0.024000</td>
#                         <td id="T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col6" class="data row0 col6" >-0.073000</td>
#                         <td id="T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col7" class="data row0 col7" >0.037000</td>
#                         <td id="T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col8" class="data row0 col8" >-0.011000</td>
#                         <td id="T_6f211654_9f65_11ea_984f_0b9c68c508d6row0_col9" class="data row0 col9" >0.007000</td>
#             </tr>
#     </tbody></table>

# %%
end_matrix = torch.Tensor.cpu(model.crf.end_matrix.view(
    1, -1)).detach().numpy()
df = pd.DataFrame(end_matrix, columns=id2tag.values())
df.reindex(index, axis=1).round(3).style.applymap(
    lambda v: 'background-color: %s' % '#B0C4DE'
    if v > 0 else 'background-color: %s' % '#FFFFFF')
# Out:
# <style  type="text/css" >
#     #T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col0 {
#             background-color:  #B0C4DE;
#         }    #T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col1 {
#             background-color:  #FFFFFF;
#         }    #T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col2 {
#             background-color:  #FFFFFF;
#         }    #T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col3 {
#             background-color:  #B0C4DE;
#         }    #T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col4 {
#             background-color:  #FFFFFF;
#         }    #T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col5 {
#             background-color:  #B0C4DE;
#         }    #T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col6 {
#             background-color:  #B0C4DE;
#         }    #T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col7 {
#             background-color:  #FFFFFF;
#         }    #T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col8 {
#             background-color:  #FFFFFF;
#         }    #T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col9 {
#             background-color:  #FFFFFF;
#         }</style><table id="T_808647de_9f65_11ea_984f_0b9c68c508d6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >B_nt</th>        <th class="col_heading level0 col1" >M_nt</th>        <th class="col_heading level0 col2" >E_nt</th>        <th class="col_heading level0 col3" >B_nr</th>        <th class="col_heading level0 col4" >M_nr</th>        <th class="col_heading level0 col5" >E_nr</th>        <th class="col_heading level0 col6" >B_ns</th>        <th class="col_heading level0 col7" >M_ns</th>        <th class="col_heading level0 col8" >E_ns</th>        <th class="col_heading level0 col9" >O</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_808647de_9f65_11ea_984f_0b9c68c508d6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col0" class="data row0 col0" >0.093000</td>
#                         <td id="T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col1" class="data row0 col1" >-0.043000</td>
#                         <td id="T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col2" class="data row0 col2" >-0.071000</td>
#                         <td id="T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col3" class="data row0 col3" >0.059000</td>
#                         <td id="T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col4" class="data row0 col4" >-0.100000</td>
#                         <td id="T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col5" class="data row0 col5" >0.062000</td>
#                         <td id="T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col6" class="data row0 col6" >0.011000</td>
#                         <td id="T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col7" class="data row0 col7" >-0.075000</td>
#                         <td id="T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col8" class="data row0 col8" >-0.001000</td>
#                         <td id="T_808647de_9f65_11ea_984f_0b9c68c508d6row0_col9" class="data row0 col9" >-0.030000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # TODO
# > 以字为单位进行的实体识别，以词为单位效果会不会更好？？
